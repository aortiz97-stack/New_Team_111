# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn import preprocessing
import statsmodels.api as sm
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import OneHotEncoder
import patsy
from statsmodels.stats.outliers_influence import variance_inflation_factor
# %matplotlib inline

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df = pd.read_csv("Data/county_data_clean.csv")

# %% [markdown]
# #### Dataframe for State and Counties

# %%
df_states = df[df["county_fips_code"] == 0] #Dataframe for states only
df_counties = df[df["county_fips_code"] != 0] #Dataframe for counties only

# %%
df_counties = df_counties.set_index("name")
df_states = df_states.set_index("name")

# %%
df_counties = df_counties.drop(["Unnamed: 0"], axis=1)
df_states = df_states.drop(["Unnamed: 0"], axis=1)

# %%
df_counties["insured_adults_raw"] = df_counties["adult_population_18_64"] - df_counties["uninsured_adults_raw"]

# %% [markdown]
# #### Dropping columns

# %%
df_counties = df_counties.drop(["Kalawao County"]) # Only NA's in response variable

# %%
df_counties = df_counties.drop(["state_fips_code", "state_abbreviation", "county_fips_code", "5_digit_fips_code"], axis = 1)

# %%
df_counties.shape #3142 counties, 154 columns
# Out:
# (3141, 154)

# %%
df_counties.isna().mean().sort_values(ascending = True)
# Out:
# insured_adults_raw                                                      0.000000
# uninsured_children                                                      0.000000
# adult_population_18_64                                                  0.000000
# uninsured_adults_raw                                                    0.000000
# uninsured_adults                                                        0.000000
# insufficient_sleep                                                      0.000000
# food_insecurity                                                         0.000000
# diabetes_prevalence                                                     0.000000
# frequent_mental_distress                                                0.000000
# frequent_physical_distress                                              0.000000
# median_household_income                                                 0.000000
# some_college                                                            0.000000
# children_in_poverty                                                     0.000000
# long_commute_driving_alone                                              0.000000
# driving_alone_to_work                                                   0.000000
# percentage_of_households_with_lack_of_kitchen_or_plumbing_facilities    0.000000
# income_inequality                                                       0.000000
# children_in_single_parent_households                                    0.000000
# social_associations                                                     0.000000
# percentage_of_households_with_overcrowding                              0.000000
# percentage_of_households_with_high_housing_costs                        0.000000
# unemployment                                                            0.000000
# homeownership                                                           0.000000
# severe_housing_problems                                                 0.000000
# excessive_drinking                                                      0.000000
# percent_native_hawaiian_other_pacific_islander                          0.000000
# percent_asian                                                           0.000000
# adult_smoking                                                           0.000000
# poor_mental_health_days                                                 0.000000
# adult_obesity                                                           0.000000
# uninsured                                                               0.000000
# physical_inactivity                                                     0.000000
# poor_physical_health_days                                               0.000000
# percent_hispanic                                                        0.000000
# percent_non_hispanic_white                                              0.000000
# poor_or_fair_health                                                     0.000000
# percent_american_indian_and_alaskan_native                              0.000000
# percent_non_hispanic_african_american                                   0.000000
# percent_not_proficient_in_english                                       0.000000
# percent_65_and_older                                                    0.000000
# percent_females                                                         0.000000
# percent_below_18_years_of_age                                           0.000000
# population                                                              0.000000
# severe_housing_cost_burden                                              0.000318
# access_to_exercise_opportunities                                        0.001910
# percent_rural                                                           0.002229
# flu_vaccinations                                                        0.004776
# mammography_screening                                                   0.005731
# food_environment_index                                                  0.006049
# limited_access_to_healthy_foods                                         0.006049
# ratio_of_population_to_primary_care_providers_other_than_physicians     0.008278
# other_primary_care_providers                                            0.008278
# alcohol_impaired_driving_deaths                                         0.010188
# air_pollution_particulate_matter                                        0.010506
# preventable_hospital_stays                                              0.011780
# drinking_water_violations                                               0.013372
# premature_age_adjusted_mortality                                        0.019102
# premature_death                                                         0.019102
# life_expectancy                                                         0.021649
# ratio_of_population_to_dentists                                         0.027061
# dentists                                                                0.027061
# high_school_graduation                                                  0.031200
# injury_deaths                                                           0.032474
# low_birthweight                                                         0.033747
# children_eligible_for_free_or_reduced_price_lunch                       0.038204
# primary_care_physicians                                                 0.042980
# ratio_of_population_to_primary_care_physicians                          0.042980
# teen_births                                                             0.045527
# sexually_transmitted_infections                                         0.049984
# violent_crime                                                           0.060490
# ratio_of_population_to_mental_health_providers                          0.080229
# mental_health_providers                                                 0.080229
# children_in_poverty_white                                               0.097740
# residential_segregation_non_white_white                                 0.110156
# median_household_income_white                                           0.128940
# motor_vehicle_crash_deaths                                              0.140401
# children_in_poverty_hispanic                                            0.149316
# median_household_income_hispanic                                        0.219994
# hiv_prevalence                                                          0.228271
# flu_vaccinations_white                                                  0.268067
# firearm_fatalities                                                      0.296721
# residential_segregation_black_white                                     0.344476
# children_in_poverty_black                                               0.361350
# mammography_screening_white                                             0.374085
# median_household_income_black                                           0.383954
# teen_births_white                                                       0.386819
# child_mortality                                                         0.388730
# flu_vaccinations_black                                                  0.410697
# flu_vaccinations_hispanic                                               0.415154
# low_birthweight_white                                                   0.421840
# preventable_hospital_stays_white                                        0.434893
# life_expectancy_white                                                   0.450493
# drug_overdose_deaths                                                    0.452404
# driving_alone_to_work_white                                             0.471188
# premature_age_adjusted_mortality_white                                  0.496657
# premature_death_white                                                   0.496975
# teen_births_hispanic                                                    0.498567
# mammography_screening_black                                             0.508118
# preventable_hospital_stays_black                                        0.528494
# disconnected_youth                                                      0.550462
# low_birthweight_hispanic                                                0.553009
# low_birthweight_black                                                   0.557784
# teen_births_black                                                       0.558103
# mammography_screening_hispanic                                          0.560331
# premature_age_adjusted_mortality_black                                  0.569245
# premature_death_black                                                   0.569564
# life_expectancy_black                                                   0.573703
# driving_alone_to_work_hispanic                                          0.591213
# homicides                                                               0.595033
# infant_mortality                                                        0.598854
# life_expectancy_hispanic                                                0.602993
# driving_alone_to_work_black                                             0.624960
# preventable_hospital_stays_hispanic                                     0.676218
# premature_death_hispanic                                                0.733206
# premature_age_adjusted_mortality_hispanic                               0.733206
# child_mortality_white                                                   0.802292
# child_mortality_black                                                   0.838268
# infant_mortality_white                                                  0.870742
# child_mortality_hispanic                                                0.880930
# infant_mortality_black                                                  0.888571
# infant_mortality_hispanic                                               0.926138
# w_2_enrollment                                                          0.977077
# female_population_0_17                                                  0.977077
# total_male_population                                                   0.977077
# male_population_65                                                      0.977077
# male_population_45_64                                                   0.977077
# male_population_18_44                                                   0.977077
# male_population_0_17                                                    0.977077
# year_structure_built                                                    0.977077
# female_population_65                                                    0.977077
# injury_hospitalizations                                                 0.977077
# child_abuse                                                             0.977077
# communicable_disease                                                    0.977077
# older_adults_living_alone                                               0.977077
# female_population_18_44                                                 0.977077
# poverty                                                                 0.977077
# reading_proficiency                                                     0.977077
# childhood_immunizations                                                 0.977077
# on_road_motor_vehicle_crash_related_er_visits                           0.977077
# motor_vehicle_crash_occupancy_rate                                      0.977077
# total_female_population                                                 0.977077
# smoking_during_pregnancy                                                0.977077
# cancer_incidence                                                        0.977077
# population_growth                                                       0.977077
# female_population_45_64                                                 0.977077
# off_road_motor_vehicle_crash_related_er_visits                          0.977396
# opioid_hospital_visits                                                  0.977396
# drug_arrests                                                            0.977396
# cerebrovascular_disease_hospitalizations                                0.977714
# coronary_heart_disease_hospitalizations                                 0.977714
# self_inflicted_injury_hospitalizations                                  0.978032
# fall_fatalities_65                                                      0.979624
# alcohol_related_hospitalizations                                        0.980261
# hate_crimes                                                             0.996180
# dtype: float64

# %%
df_counties.columns[df_counties.columns.str.endswith('_black')]
# Out:
# Index(['premature_death_black', 'low_birthweight_black', 'teen_births_black',
#        'preventable_hospital_stays_black', 'mammography_screening_black',
#        'flu_vaccinations_black', 'children_in_poverty_black',
#        'driving_alone_to_work_black', 'life_expectancy_black',
#        'premature_age_adjusted_mortality_black', 'child_mortality_black',
#        'infant_mortality_black', 'median_household_income_black'],
#       dtype='object')

# %%
df_counties.columns[df_counties.columns.str.endswith('_white')]
# Out:
# Index(['premature_death_white', 'low_birthweight_white', 'teen_births_white',
#        'preventable_hospital_stays_white', 'mammography_screening_white',
#        'flu_vaccinations_white', 'children_in_poverty_white',
#        'driving_alone_to_work_white', 'life_expectancy_white',
#        'premature_age_adjusted_mortality_white', 'child_mortality_white',
#        'infant_mortality_white', 'median_household_income_white',
#        'residential_segregation_black_white',
#        'residential_segregation_non_white_white',
#        'percent_non_hispanic_white'],
#       dtype='object')

# %%
df_counties.columns[df_counties.columns.str.endswith('_hispanic')]
# Out:
# Index(['premature_death_hispanic', 'low_birthweight_hispanic',
#        'teen_births_hispanic', 'preventable_hospital_stays_hispanic',
#        'mammography_screening_hispanic', 'flu_vaccinations_hispanic',
#        'children_in_poverty_hispanic', 'driving_alone_to_work_hispanic',
#        'life_expectancy_hispanic', 'premature_age_adjusted_mortality_hispanic',
#        'child_mortality_hispanic', 'infant_mortality_hispanic',
#        'median_household_income_hispanic', 'percent_hispanic'],
#       dtype='object')

# %%
df_counties = df_counties.drop(['premature_death_black', 'low_birthweight_black', 'teen_births_black',
                                'preventable_hospital_stays_black', 'mammography_screening_black',
                                'flu_vaccinations_black', 'children_in_poverty_black',
                                'driving_alone_to_work_black', 'life_expectancy_black',
                                'premature_age_adjusted_mortality_black', 'child_mortality_black',
                                'infant_mortality_black', 'median_household_income_black', 
                                'premature_death_white', 'low_birthweight_white', 'teen_births_white',
                                'preventable_hospital_stays_white', 'mammography_screening_white',
                                'flu_vaccinations_white', 'children_in_poverty_white',
                                'driving_alone_to_work_white', 'life_expectancy_white',
                                'premature_age_adjusted_mortality_white', 'child_mortality_white',
                                'infant_mortality_white', 'median_household_income_white',
                                'premature_death_hispanic', 'low_birthweight_hispanic',
                                'teen_births_hispanic', 'preventable_hospital_stays_hispanic',
                                'mammography_screening_hispanic', 'flu_vaccinations_hispanic',
                                'children_in_poverty_hispanic', 'driving_alone_to_work_hispanic',
                                'life_expectancy_hispanic', 'premature_age_adjusted_mortality_hispanic',
                                'child_mortality_hispanic', 'infant_mortality_hispanic',
                                'median_household_income_hispanic'], axis = 1)

# %%
df_counties_missing = df_counties.isna().mean().sort_values(ascending = True)
df_counties_missing[df_counties_missing > 0.7] # Most of these only have available data for the state of Wisconsin.
# Out:
# injury_hospitalizations                           0.977077
# year_structure_built                              0.977077
# male_population_0_17                              0.977077
# male_population_18_44                             0.977077
# male_population_45_64                             0.977077
# total_female_population                           0.977077
# total_male_population                             0.977077
# female_population_0_17                            0.977077
# female_population_18_44                           0.977077
# female_population_45_64                           0.977077
# female_population_65                              0.977077
# child_abuse                                       0.977077
# male_population_65                                0.977077
# older_adults_living_alone                         0.977077
# motor_vehicle_crash_occupancy_rate                0.977077
# w_2_enrollment                                    0.977077
# population_growth                                 0.977077
# reading_proficiency                               0.977077
# childhood_immunizations                           0.977077
# communicable_disease                              0.977077
# cancer_incidence                                  0.977077
# on_road_motor_vehicle_crash_related_er_visits     0.977077
# smoking_during_pregnancy                          0.977077
# poverty                                           0.977077
# opioid_hospital_visits                            0.977396
# off_road_motor_vehicle_crash_related_er_visits    0.977396
# drug_arrests                                      0.977396
# cerebrovascular_disease_hospitalizations          0.977714
# coronary_heart_disease_hospitalizations           0.977714
# self_inflicted_injury_hospitalizations            0.978032
# fall_fatalities_65                                0.979624
# alcohol_related_hospitalizations                  0.980261
# hate_crimes                                       0.996180
# dtype: float64

# %%
df_counties = df_counties.drop(df_counties_missing[df_counties_missing > 0.7].index, axis = 1)

# %%
df_counties.isna().mean().sort_values(ascending = True) # These are the variables that will be included in the model.
# Out:
# long_commute_driving_alone                                              0.000000
# percentage_of_households_with_high_housing_costs                        0.000000
# percentage_of_households_with_overcrowding                              0.000000
# percentage_of_households_with_lack_of_kitchen_or_plumbing_facilities    0.000000
# driving_alone_to_work                                                   0.000000
# frequent_physical_distress                                              0.000000
# frequent_mental_distress                                                0.000000
# diabetes_prevalence                                                     0.000000
# food_insecurity                                                         0.000000
# insufficient_sleep                                                      0.000000
# uninsured_adults                                                        0.000000
# uninsured_adults_raw                                                    0.000000
# adult_population_18_64                                                  0.000000
# severe_housing_problems                                                 0.000000
# uninsured_children                                                      0.000000
# homeownership                                                           0.000000
# population                                                              0.000000
# percent_below_18_years_of_age                                           0.000000
# percent_65_and_older                                                    0.000000
# percent_non_hispanic_african_american                                   0.000000
# percent_american_indian_and_alaskan_native                              0.000000
# percent_asian                                                           0.000000
# percent_native_hawaiian_other_pacific_islander                          0.000000
# percent_hispanic                                                        0.000000
# percent_non_hispanic_white                                              0.000000
# percent_not_proficient_in_english                                       0.000000
# percent_females                                                         0.000000
# median_household_income                                                 0.000000
# social_associations                                                     0.000000
# insured_adults_raw                                                      0.000000
# income_inequality                                                       0.000000
# excessive_drinking                                                      0.000000
# physical_inactivity                                                     0.000000
# uninsured                                                               0.000000
# adult_smoking                                                           0.000000
# poor_mental_health_days                                                 0.000000
# some_college                                                            0.000000
# adult_obesity                                                           0.000000
# children_in_poverty                                                     0.000000
# poor_or_fair_health                                                     0.000000
# unemployment                                                            0.000000
# poor_physical_health_days                                               0.000000
# children_in_single_parent_households                                    0.000000
# severe_housing_cost_burden                                              0.000318
# access_to_exercise_opportunities                                        0.001910
# percent_rural                                                           0.002229
# flu_vaccinations                                                        0.004776
# mammography_screening                                                   0.005731
# food_environment_index                                                  0.006049
# limited_access_to_healthy_foods                                         0.006049
# ratio_of_population_to_primary_care_providers_other_than_physicians     0.008278
# other_primary_care_providers                                            0.008278
# alcohol_impaired_driving_deaths                                         0.010188
# air_pollution_particulate_matter                                        0.010506
# preventable_hospital_stays                                              0.011780
# drinking_water_violations                                               0.013372
# premature_death                                                         0.019102
# premature_age_adjusted_mortality                                        0.019102
# life_expectancy                                                         0.021649
# dentists                                                                0.027061
# ratio_of_population_to_dentists                                         0.027061
# high_school_graduation                                                  0.031200
# injury_deaths                                                           0.032474
# low_birthweight                                                         0.033747
# children_eligible_for_free_or_reduced_price_lunch                       0.038204
# primary_care_physicians                                                 0.042980
# ratio_of_population_to_primary_care_physicians                          0.042980
# teen_births                                                             0.045527
# sexually_transmitted_infections                                         0.049984
# violent_crime                                                           0.060490
# ratio_of_population_to_mental_health_providers                          0.080229
# mental_health_providers                                                 0.080229
# residential_segregation_non_white_white                                 0.110156
# motor_vehicle_crash_deaths                                              0.140401
# hiv_prevalence                                                          0.228271
# firearm_fatalities                                                      0.296721
# residential_segregation_black_white                                     0.344476
# child_mortality                                                         0.388730
# drug_overdose_deaths                                                    0.452404
# disconnected_youth                                                      0.550462
# homicides                                                               0.595033
# infant_mortality                                                        0.598854
# dtype: float64

# %%
df_counties.shape #3142 counties, 82 columns
# Out:
# (3141, 82)

# %% [markdown]
# #### Labels and Features

# %%
labels = df_counties[['uninsured_adults_raw','insured_adults_raw']]

# %%
features = df_counties.drop(["uninsured_adults",  
                      "uninsured_children", 
                      "uninsured",
                      "uninsured_adults_raw",
                      "insured_adults_raw",
                      "population",
                      "adult_population_18_64"], axis = 1)

# %%
feature_list = list(features.columns)

# %% [markdown]
# #### Splitting into training and test set

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.3, random_state = 123)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (2198, 75)
# Training Labels Shape: (2198, 2)
# Testing Features Shape: (943, 75)
# Testing Labels Shape: (943, 2)

# %% [markdown]
# #### Imputing Missing Values

# %%
imp = IterativeImputer(max_iter=50, random_state=123)
imp.fit(train_features)
train_features = imp.transform(train_features)

# %%
imp.fit(test_features)
test_features = imp.transform(test_features)

# %% [markdown]
# #### Standardizing Data

# %%
scaler = preprocessing.StandardScaler()
scaler.fit(train_features) 
train_features = scaler.transform(train_features)

# %%
scaler.fit(test_features)
test_features = scaler.transform(test_features)

# %% [markdown]
# #### Checking for Multicollinearity

# %%
vif_scores = pd.DataFrame() 
vif_scores["Attribute"] = feature_list
  
# calculating VIF for each feature 
vif_scores["VIF Scores"] = [variance_inflation_factor(train_features, i) for i in range(len(feature_list))] 
  
display(vif_scores.sort_values(by = "VIF Scores", ascending = False))
# Out:
#                                             Attribute   VIF Scores
# 7                              food_environment_index  1688.463077
# 49                    limited_access_to_healthy_foods   728.871043
# 48                                    food_insecurity   723.735304
# 71                         percent_non_hispanic_white   521.410609
# 66              percent_non_hispanic_african_american   277.863017
# 70                                   percent_hispanic   240.549643
# 44                         frequent_physical_distress   203.702582
# 2                           poor_physical_health_days   114.120908
# 45                           frequent_mental_distress   112.988216
# 67         percent_american_indian_and_alaskan_native    91.137955
# 34                            severe_housing_problems    87.748226
# 0                                     premature_death    57.284600
# 35   percentage_of_households_with_high_housing_costs    56.759190
# 3                             poor_mental_health_days    50.157548
# 41                   premature_age_adjusted_mortality    49.154443
# 1                                 poor_or_fair_health    30.599786
# 36         percentage_of_households_with_overcrowding    17.730398
# 40                                    life_expectancy    15.652648
# 31                                      injury_deaths    15.356599
# 42                                    child_mortality    14.209626
# 68                                      percent_asian    13.162990
# 60                                          homicides    12.095171
# 61                                 firearm_fatalities    10.535209
# 43                                   infant_mortality    10.369759
# 26                                children_in_poverty     9.563647
# 50                               drug_overdose_deaths     9.470502
# 51                         motor_vehicle_crash_deaths     9.247484
# 5                                       adult_smoking     9.088429
# 37  percentage_of_households_with_lack_of_kitchen_...     8.529446
# 63                         severe_housing_cost_burden     7.937010
# 56                            median_household_income     7.585819
# 65                               percent_65_and_older     7.373721
# 13                                        teen_births     6.617098
# 46                                diabetes_prevalence     6.188268
# 52                                 insufficient_sleep     5.321395
# 55                                 disconnected_youth     5.235132
# 74                                      percent_rural     5.117642
# 64                      percent_below_18_years_of_age     5.088043
# 72                  percent_not_proficient_in_english     4.673310
# 24                                       some_college     4.324135
# 12                    sexually_transmitted_infections     4.267688
# 57  children_eligible_for_free_or_reduced_price_lunch     4.204944
# 8                                 physical_inactivity     4.179562
# 62                                      homeownership     4.128351
# 28               children_in_single_parent_households     3.669753
# 10                                 excessive_drinking     3.642926
# 47                                     hiv_prevalence     3.479577
# 6                                       adult_obesity     3.351183
# 58                residential_segregation_black_white     3.305810
# 32                   air_pollution_particulate_matter     3.277204
# 4                                     low_birthweight     3.180990
# 73                                    percent_females     3.120790
# 38                              driving_alone_to_work     3.007314
# 59            residential_segregation_non_white_white     2.895838
# 14                            primary_care_physicians     2.675686
# 39                         long_commute_driving_alone     2.615901
# 25                                       unemployment     2.598106
# 29                                social_associations     2.541848
# 27                                  income_inequality     2.476157
# 69     percent_native_hawaiian_other_pacific_islander     2.406648
# 9                    access_to_exercise_opportunities     2.392348
# 21                              mammography_screening     2.325203
# 30                                      violent_crime     2.150365
# 22                                   flu_vaccinations     2.110014
# 17                    ratio_of_population_to_dentists     2.085469
# 18                            mental_health_providers     2.052291
# 16                                           dentists     1.967838
# 53                       other_primary_care_providers     1.940103
# 20                         preventable_hospital_stays     1.796920
# 15     ratio_of_population_to_primary_care_physicians     1.760171
# 19     ratio_of_population_to_mental_health_providers     1.738215
# 23                             high_school_graduation     1.663317
# 54  ratio_of_population_to_primary_care_providers_...     1.433493
# 33                          drinking_water_violations     1.207227
# 11                    alcohol_impaired_driving_deaths     1.168867

# %%
train_dataframe = pd.DataFrame(train_features, columns = feature_list)

# %%
train_dataframe = train_dataframe.drop(["food_environment_index",
                                       "frequent_physical_distress",
                                       "frequent_mental_distress"], axis = 1)
train_features = np.array(train_dataframe)
feature_list = train_dataframe.columns

# %%
vif_scores = pd.DataFrame() 
vif_scores["Attribute"] = feature_list
  
# calculating VIF for each feature 
vif_scores["VIF Scores"] = [variance_inflation_factor(train_features, i) for i in range(len(feature_list))] 
  
display(vif_scores.sort_values(by = "VIF Scores", ascending = False))
# Out:
#                                             Attribute  VIF Scores
# 68                         percent_non_hispanic_white  519.386162
# 63              percent_non_hispanic_african_american  276.790980
# 67                                   percent_hispanic  237.827630
# 64         percent_american_indian_and_alaskan_native   90.109128
# 33                            severe_housing_problems   87.491646
# 0                                     premature_death   57.209913
# 34   percentage_of_households_with_high_housing_costs   56.474264
# 40                   premature_age_adjusted_mortality   49.079452
# 1                                 poor_or_fair_health   24.127258
# 2                           poor_physical_health_days   21.931377
# 35         percentage_of_households_with_overcrowding   17.645699
# 39                                    life_expectancy   15.632654
# 30                                      injury_deaths   15.329093
# 41                                    child_mortality   14.162966
# 65                                      percent_asian   13.066313
# 3                             poor_mental_health_days   12.092174
# 57                                          homicides   12.057708
# 58                                 firearm_fatalities   10.531096
# 42                                   infant_mortality   10.348645
# 47                               drug_overdose_deaths    9.455400
# 25                                children_in_poverty    9.337569
# 48                         motor_vehicle_crash_deaths    9.236357
# 36  percentage_of_households_with_lack_of_kitchen_...    8.521350
# 5                                       adult_smoking    8.401849
# 60                         severe_housing_cost_burden    7.935858
# 53                            median_household_income    7.491718
# 62                               percent_65_and_older    7.367090
# 45                                    food_insecurity    6.881537
# 12                                        teen_births    6.557476
# 43                                diabetes_prevalence    6.150483
# 49                                 insufficient_sleep    5.289334
# 52                                 disconnected_youth    5.225491
# 71                                      percent_rural    5.094035
# 61                      percent_below_18_years_of_age    5.077437
# 69                  percent_not_proficient_in_english    4.615264
# 23                                       some_college    4.303379
# 11                    sexually_transmitted_infections    4.260976
# 54  children_eligible_for_free_or_reduced_price_lunch    4.161056
# 7                                 physical_inactivity    4.115164
# 59                                      homeownership    4.104572
# 27               children_in_single_parent_households    3.667537
# 9                                  excessive_drinking    3.534716
# 44                                     hiv_prevalence    3.476433
# 6                                       adult_obesity    3.327312
# 55                residential_segregation_black_white    3.304728
# 31                   air_pollution_particulate_matter    3.222965
# 4                                     low_birthweight    3.171845
# 70                                    percent_females    3.010377
# 37                              driving_alone_to_work    3.001402
# 56            residential_segregation_non_white_white    2.892865
# 13                            primary_care_physicians    2.671949
# 38                         long_commute_driving_alone    2.612164
# 24                                       unemployment    2.582798
# 28                                social_associations    2.533845
# 26                                  income_inequality    2.460405
# 66     percent_native_hawaiian_other_pacific_islander    2.401317
# 8                    access_to_exercise_opportunities    2.386555
# 20                              mammography_screening    2.260148
# 29                                      violent_crime    2.143971
# 21                                   flu_vaccinations    2.094813
# 16                    ratio_of_population_to_dentists    2.080289
# 17                            mental_health_providers    2.034514
# 15                                           dentists    1.965828
# 50                       other_primary_care_providers    1.937637
# 46                    limited_access_to_healthy_foods    1.794348
# 19                         preventable_hospital_stays    1.787199
# 14     ratio_of_population_to_primary_care_physicians    1.759182
# 18     ratio_of_population_to_mental_health_providers    1.736191
# 22                             high_school_graduation    1.656773
# 51  ratio_of_population_to_primary_care_providers_...    1.429311
# 32                          drinking_water_violations    1.205110
# 10                    alcohol_impaired_driving_deaths    1.168000

# %%
train_dataframe = train_dataframe.drop(["severe_housing_problems",
                                       "premature_age_adjusted_mortality",
                                       "poor_or_fair_health",
                                       "premature_death"], axis = 1)
train_features = np.array(train_dataframe)
feature_list = train_dataframe.columns

# %%
vif_scores = pd.DataFrame() 
vif_scores["Attribute"] = feature_list
  
# calculating VIF for each feature 
vif_scores["VIF Scores"] = [variance_inflation_factor(train_features, i) for i in range(len(feature_list))] 
  
display(vif_scores.sort_values(by = "VIF Scores", ascending = False))
# Out:
#                                             Attribute  VIF Scores
# 64                         percent_non_hispanic_white  507.847307
# 59              percent_non_hispanic_african_american  269.809476
# 63                                   percent_hispanic  229.056320
# 60         percent_american_indian_and_alaskan_native   87.225305
# 0                           poor_physical_health_days   16.478465
# 28                                      injury_deaths   14.949878
# 61                                      percent_asian   12.809459
# 1                             poor_mental_health_days   12.027765
# 53                                          homicides   11.294789
# 54                                 firearm_fatalities   10.262753
# 37                                    child_mortality   10.004369
# 38                                   infant_mortality    9.924902
# 23                                children_in_poverty    9.127384
# 44                         motor_vehicle_crash_deaths    8.366049
# 43                               drug_overdose_deaths    7.891944
# 56                         severe_housing_cost_burden    7.854638
# 36                                    life_expectancy    7.698844
# 31   percentage_of_households_with_high_housing_costs    7.410197
# 49                            median_household_income    7.401906
# 3                                       adult_smoking    7.191828
# 58                               percent_65_and_older    7.181233
# 41                                    food_insecurity    6.825846
# 10                                        teen_births    6.318944
# 39                                diabetes_prevalence    6.103097
# 45                                 insufficient_sleep    5.279009
# 67                                      percent_rural    5.067244
# 57                      percent_below_18_years_of_age    5.015810
# 48                                 disconnected_youth    4.955533
# 65                  percent_not_proficient_in_english    4.523289
# 9                     sexually_transmitted_infections    4.245081
# 21                                       some_college    4.231239
# 50  children_eligible_for_free_or_reduced_price_lunch    4.097003
# 55                                      homeownership    4.022913
# 5                                 physical_inactivity    3.970727
# 25               children_in_single_parent_households    3.637338
# 32         percentage_of_households_with_overcrowding    3.609669
# 7                                  excessive_drinking    3.451579
# 40                                     hiv_prevalence    3.303488
# 51                residential_segregation_black_white    3.288637
# 4                                       adult_obesity    3.271982
# 29                   air_pollution_particulate_matter    3.130534
# 2                                     low_birthweight    3.101783
# 34                              driving_alone_to_work    2.998787
# 66                                    percent_females    2.974723
# 52            residential_segregation_non_white_white    2.866857
# 11                            primary_care_physicians    2.655454
# 22                                       unemployment    2.578513
# 35                         long_commute_driving_alone    2.577843
# 26                                social_associations    2.528677
# 24                                  income_inequality    2.411487
# 62     percent_native_hawaiian_other_pacific_islander    2.372324
# 6                    access_to_exercise_opportunities    2.352406
# 18                              mammography_screening    2.207093
# 33  percentage_of_households_with_lack_of_kitchen_...    2.112457
# 27                                      violent_crime    2.107224
# 14                    ratio_of_population_to_dentists    2.055069
# 19                                   flu_vaccinations    2.050358
# 15                            mental_health_providers    2.015995
# 13                                           dentists    1.951851
# 46                       other_primary_care_providers    1.922349
# 42                    limited_access_to_healthy_foods    1.778913
# 17                         preventable_hospital_stays    1.764037
# 12     ratio_of_population_to_primary_care_physicians    1.749184
# 16     ratio_of_population_to_mental_health_providers    1.720350
# 20                             high_school_graduation    1.639753
# 47  ratio_of_population_to_primary_care_providers_...    1.414012
# 30                          drinking_water_violations    1.195626
# 8                     alcohol_impaired_driving_deaths    1.159923

# %%
train_dataframe = train_dataframe.drop(["firearm_fatalities",
                                       "homicides",
                                       "poor_physical_health_days",
                                       "poor_mental_health_days",
                                        "percent_non_hispanic_african_american",
                                        "percent_american_indian_and_alaskan_native",
                                       "percent_asian"], axis = 1)
train_features = np.array(train_dataframe)
feature_list = train_dataframe.columns

# %%
vif_scores = pd.DataFrame() 
vif_scores["Attribute"] = feature_list
  
# calculating VIF for each feature 
vif_scores["VIF Scores"] = [variance_inflation_factor(train_features, i) for i in range(len(feature_list))] 
  
display(vif_scores.sort_values(by = "VIF Scores", ascending = False))
# Out:
#                                             Attribute  VIF Scores
# 57                         percent_non_hispanic_white   10.967858
# 35                                    child_mortality    9.910934
# 36                                   infant_mortality    9.726074
# 26                                      injury_deaths    9.050638
# 21                                children_in_poverty    8.792984
# 56                                   percent_hispanic    8.093469
# 52                         severe_housing_cost_burden    7.764946
# 29   percentage_of_households_with_high_housing_costs    7.356165
# 34                                    life_expectancy    7.343289
# 42                         motor_vehicle_crash_deaths    7.342262
# 54                               percent_65_and_older    6.964208
# 47                            median_household_income    6.801798
# 39                                    food_insecurity    6.231933
# 8                                         teen_births    6.205665
# 41                               drug_overdose_deaths    6.055460
# 37                                diabetes_prevalence    5.858569
# 1                                       adult_smoking    5.027100
# 60                                      percent_rural    4.947261
# 46                                 disconnected_youth    4.886495
# 43                                 insufficient_sleep    4.572202
# 53                      percent_below_18_years_of_age    4.565628
# 58                  percent_not_proficient_in_english    4.278594
# 19                                       some_college    4.053321
# 48  children_eligible_for_free_or_reduced_price_lunch    3.978102
# 7                     sexually_transmitted_infections    3.968887
# 3                                 physical_inactivity    3.904196
# 51                                      homeownership    3.883218
# 23               children_in_single_parent_households    3.548390
# 30         percentage_of_households_with_overcrowding    3.345329
# 49                residential_segregation_black_white    3.210744
# 2                                       adult_obesity    3.168838
# 38                                     hiv_prevalence    3.045275
# 5                                  excessive_drinking    3.026403
# 27                   air_pollution_particulate_matter    2.914911
# 32                              driving_alone_to_work    2.806256
# 59                                    percent_females    2.782614
# 50            residential_segregation_non_white_white    2.700727
# 9                             primary_care_physicians    2.640839
# 0                                     low_birthweight    2.633616
# 33                         long_commute_driving_alone    2.568024
# 20                                       unemployment    2.476144
# 4                    access_to_exercise_opportunities    2.333380
# 22                                  income_inequality    2.327168
# 24                                social_associations    2.295403
# 16                              mammography_screening    2.114491
# 31  percentage_of_households_with_lack_of_kitchen_...    2.068240
# 12                    ratio_of_population_to_dentists    2.035567
# 17                                   flu_vaccinations    2.003727
# 11                                           dentists    1.934215
# 13                            mental_health_providers    1.933683
# 44                       other_primary_care_providers    1.913647
# 25                                      violent_crime    1.874295
# 40                    limited_access_to_healthy_foods    1.772466
# 10     ratio_of_population_to_primary_care_physicians    1.738601
# 14     ratio_of_population_to_mental_health_providers    1.697768
# 15                         preventable_hospital_stays    1.687734
# 18                             high_school_graduation    1.618886
# 45  ratio_of_population_to_primary_care_providers_...    1.403062
# 55     percent_native_hawaiian_other_pacific_islander    1.184765
# 28                          drinking_water_violations    1.162645
# 6                     alcohol_impaired_driving_deaths    1.154338

# %% [markdown]
# #### Recursive Feature Elimination

# %%
rfe = RFE(estimator=DecisionTreeRegressor(), n_features_to_select=10)
fit = rfe.fit(train_features, train_labels)

# %%
indices = [i for i, x in enumerate(fit.support_) if x]
selected_features = pd.Series(feature_list)[indices]

# %%
train_set = pd.DataFrame(train_features[:, indices], columns = selected_features)
train_labels2 = train_labels.reset_index(drop = True)
train_set["uninsured_adults_raw"] = train_labels2["uninsured_adults_raw"]
train_set["insured_adults_raw"] = train_labels2["insured_adults_raw"]

# %%
train_set.head()
# Out:
#    ratio_of_population_to_mental_health_providers  social_associations  \
# 0                                       -0.557078             0.807273
# 1                                       -0.174280            -0.895459
# 2                                        5.861612             0.246081
# 3                                       -0.658379            -1.205257
# 4                                       -0.361064            -0.095948
#
#    air_pollution_particulate_matter  long_commute_driving_alone  \
# 0                          1.313382                   -0.582349
# 1                         -0.802664                   -0.680096
# 2                          0.378385                    1.030484
# 3                         -0.212140                   -1.844920
# 4                          1.165750                   -0.085466
#
#    hiv_prevalence  food_insecurity  disconnected_youth  homeownership  \
# 0       -0.302138        -0.279423           -0.433537       0.106717
# 1       -0.506553        -0.994434           -0.292837       1.699963
# 2       -0.418796        -0.207921            1.491757       0.606093
# 3       -0.410389         0.745427            0.727960      -1.163297
# 4       -0.423000        -0.446259           -0.958878       0.037638
#
#    percent_non_hispanic_white  percent_rural  uninsured_adults_raw  \
# 0                    0.663090      -0.751565                2729.0
# 1                    0.837317       1.309701                 689.0
# 2                    0.929361       1.309701                1290.0
# 3                   -0.647417      -0.787117                1348.0
# 4                    0.770783      -0.183910                2647.0
#
#    insured_adults_raw
# 0             36329.0
# 1              6311.0
# 2              8604.0
# 3             13069.0
# 4             19300.0

# %% [markdown]
# #### Fitting the Model

# %%
def formula_from_cols(features):
    return ' ~ ' + ' + '.join([col for col in features])

# %%
glm_formula = 'uninsured_adults_raw + insured_adults_raw' + formula_from_cols(selected_features)

# %%
glm_formula
# Out:
# 'uninsured_adults_raw + insured_adults_raw ~ ratio_of_population_to_mental_health_providers + social_associations + air_pollution_particulate_matter + long_commute_driving_alone + hiv_prevalence + food_insecurity + disconnected_youth + homeownership + percent_non_hispanic_white + percent_rural'

# %%
binom_glm = smf.glm(formula = glm_formula, data = train_set, family = sm.families.Binomial())

# %%
binom_results = binom_glm.fit()

# %%
binom_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                Generalized Linear Model Regression Results
# ==========================================================================================================
# Dep. Variable:     ['uninsured_adults_raw', 'insured_adults_raw']   No. Observations:                 2198
# Model:                                                        GLM   Df Residuals:                     2187
# Model Family:                                            Binomial   Df Model:                           10
# Link Function:                                              logit   Scale:                          1.0000
# Method:                                                      IRLS   Log-Likelihood:            -1.0554e+06
# Date:                                            Sun, 08 Aug 2021   Deviance:                   2.0905e+06
# Time:                                                    21:14:28   Pearson chi2:                 2.09e+06
# No. Iterations:                                                 6
# Covariance Type:                                        nonrobust
# ==================================================================================================================
#                                                      coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# Intercept                                         -1.9217      0.001  -3472.332      0.000      -1.923      -1.921
# ratio_of_population_to_mental_health_providers     0.1194      0.001    221.179      0.000       0.118       0.121
# social_associations                               -0.1108      0.001   -151.702      0.000      -0.112      -0.109
# air_pollution_particulate_matter                  -0.0495      0.000   -168.554      0.000      -0.050      -0.049
# long_commute_driving_alone                        -0.0860      0.000   -218.093      0.000      -0.087      -0.085
# hiv_prevalence                                     0.0213      0.000     78.306      0.000       0.021       0.022
# food_insecurity                                    0.1021      0.000    271.329      0.000       0.101       0.103
# disconnected_youth                                 0.1003      0.001    168.746      0.000       0.099       0.101
# homeownership                                      0.0912      0.000    260.824      0.000       0.091       0.092
# percent_non_hispanic_white                        -0.3507      0.000   -873.771      0.000      -0.352      -0.350
# percent_rural                                      0.1173      0.001    190.098      0.000       0.116       0.118
# ==================================================================================================================
# """

# %%
actual = train_labels["uninsured_adults_raw"] / ( train_labels["uninsured_adults_raw"] +  train_labels["insured_adults_raw"])

# %%
validation = pd.DataFrame(binom_results.fittedvalues, columns = ["fitted"])
validation["actual"] = actual.values

# %%
validation["errors"]=(validation["fitted"] - validation["actual"])**2

# %%
fig, ax = plt.subplots()
ax.scatter(validation["actual"], validation["fitted"])
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
ax.set_aspect('equal')
ax.set_xlim(lims)
ax.set_ylim(lims)
# Out:
# (0.011548798270079305, 0.7248402251372394)
