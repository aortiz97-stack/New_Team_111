# %%
import pandas as pd

# %%
def create_df(file_name, skip_rows = [0]):
    """
    This file creates a data frame from reading a provided `file_name`.
    
    Arguments:
    `file_name`: name of the file, string
    `skip_rows`: array, tells which rows to skip when reading a csv file
    
    Output:
    `df`: a dataframe containing `file_name` contents
    """
    path = 'Data/' + file_name
    df = pd.read_csv(path, skiprows = skip_rows)
    return df

# %%
def rename_df(df):
    """
    This function renames the columns in a dataframe by converting original column names to lowercase,
    removing special characters, and adding a descriptor to the original column name to identify the dataset it came from.
    
    Arguments:
    
    Output:
    `df`: a dataframe with the new column names
    """
    
    column_names = {}
    for name in df.columns:
        column_names[name] = name.replace(",","").replace(" - ","_").replace(" ","_").replace("%","").lower()
    df = df.rename(columns=column_names)
    return df

# %%
def insert_nan(descriptor):
    if descriptor =='See Plan Brochure':
        return 'NaN'
    return descriptor

# %%
def string_to_float(descriptor):
    descriptor = (str(descriptor).replace("$","").replace(",","").replace("%",""))
    if descriptor != 'See Plan Brochure':
        descriptor = float(descriptor)
    return descriptor

# %%
interested_old_columns = ['Plan ID (Standard Component)','State Code', 'Metal Level', 'Issuer Name', 
                          'Plan Marketing Name','Plan Type',
                          'EHB Percent of Total Premium', 'Premium Child Age 0-14','Premium Child Age 18' , 'Premium Adult Individual Age 21',
 'Premium Adult Individual Age 27',
 'Premium Adult Individual Age 30 ',
 'Premium Adult Individual Age 40 ',
 'Premium Adult Individual Age 50 ',
 'Premium Adult Individual Age 60 ',
 'Premium Couple 21  ',
 'Premium Couple 30 ',
 'Premium Couple 40 ',
 'Premium Couple 50 ',
 'Premium Couple 60 ',
 'Couple+1 child, Age 21',
 'Couple+1 child, Age 30 ',
 'Couple+1 child, Age 40 ',
 'Couple+1 child, Age 50 ',
 'Couple+2 children, Age 21',
 'Couple+2 children, Age 30 ',
 'Couple+2 children, Age 40 ',
 'Couple+2 children, Age 50',
 'Couple+3 or more Children, Age 21',
 'Couple+3 or more Children, Age 30',
 'Couple+3 or more Children, Age 40',
 'Couple+3 or more Children, Age 50',
 'Individual+1 child, Age 21',
 'Individual+1 child, Age 30',
 'Individual+1 child, Age 40',
 'Individual+1 child, Age 50',
 'Individual+2 children, Age 21',
 'Individual+2 children, Age 30',
 'Individual+2 children, Age 40',
 'Individual+2 children, Age 50',
 'Individual+3 or more children, Age 21',
 'Individual+3 or more children, Age 30',
 'Individual+3 or more children, Age 40',
 'Individual+3 or more children, Age 50',
                          'Standard Plan Cost Sharing', 'Medical Deductible - Individual - Standard',
                          'Medical Deductible - Family - Standard',
                          'Medical Maximum Out Of Pocket - Individual - Standard',
                          'Medical Maximum Out Of Pocket - Family - Standard']

# %%
df = create_df('Individual_Market_Medical_07_25_2019.csv')
df = df[interested_old_columns]
df = rename_df(df)
df = df.rename(columns={'plan_id_(standard_component)':'plan_id','state_code':'state'})
df
#df.columns.to_list()
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3357: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
#               plan_id state metal_level  \
# 0      38344AK1060001    AK        Gold
# 1      38344AK1060002    AK      Silver
# 2      38344AK1060004    AK      Bronze
# 3      38344AK1070001    AK      Silver
# 4      38344AK1070002    AK      Bronze
# ...               ...   ...         ...
# 42231  11269WY0070018    WY      Silver
# 42232  11269WY0070019    WY      Bronze
# 42233  11269WY0070022    WY      Bronze
# 42234  11269WY0070023    WY      Silver
# 42235  11269WY0070024    WY        Gold
#
#                                     issuer_name  \
# 0      Premera Blue Cross Blue Shield of Alaska
# 1      Premera Blue Cross Blue Shield of Alaska
# 2      Premera Blue Cross Blue Shield of Alaska
# 3      Premera Blue Cross Blue Shield of Alaska
# 4      Premera Blue Cross Blue Shield of Alaska
# ...                                         ...
# 42231         Blue Cross Blue Shield of Wyoming
# 42232         Blue Cross Blue Shield of Wyoming
# 42233         Blue Cross Blue Shield of Wyoming
# 42234         Blue Cross Blue Shield of Wyoming
# 42235         Blue Cross Blue Shield of Wyoming
#
#                                 plan_marketing_name plan_type  \
# 0            Premera Blue Cross Preferred Gold 1500       PPO
# 1          Premera Blue Cross Preferred Silver 4500       PPO
# 2          Premera Blue Cross Preferred Bronze 6350       PPO
# 3      Premera Blue Cross Preferred Silver 3000 HSA       PPO
# 4      Premera Blue Cross Preferred Bronze 5250 HSA       PPO
# ...                                             ...       ...
# 42231                       BlueSelect Silver Value       PPO
# 42232                       BlueSelect Bronze Value       PPO
# 42233                     BlueSelect Bronze Balance       PPO
# 42234                     BlueSelect Silver Balance       PPO
# 42235                       BlueSelect Gold Balance       PPO
#
#       ehb_percent_of_total_premium premium_child_age_0-14  \
# 0                           97.20%                $412.00
# 1                           97.40%                $438.00
# 2                           95.90%                $290.00
# 3                           99.90%                $432.00
# 4                           99.80%                $300.00
# ...                            ...                    ...
# 42231                      100.00%                $523.77
# 42232                      100.00%                $367.41
# 42233                      100.00%                $370.02
# 42234                      100.00%                $518.82
# 42235                      100.00%                $433.20
#
#       premium_child_age_18 premium_adult_individual_age_21  ...  \
# 0                  $492.00                         $539.00  ...
# 1                  $523.00                         $572.00  ...
# 2                  $346.00                         $379.00  ...
# 3                  $515.00                         $564.00  ...
# 4                  $358.00                         $392.00  ...
# ...                    ...                             ...  ...
# 42231              $625.11                         $684.67  ...
# 42232              $438.48                         $480.27  ...
# 42233              $441.60                         $483.68  ...
# 42234              $619.19                         $678.19  ...
# 42235              $517.00                         $566.27  ...
#
#       individual+2_children_age_50 individual+3_or_more_children_age_21  \
# 0                        $1,787.00                            $1,775.00
# 1                        $1,898.00                            $1,886.00
# 2                        $1,257.00                            $1,249.00
# 3                        $1,872.00                            $1,860.00
# 4                        $1,300.00                            $1,292.00
# ...                            ...                                  ...
# 42231                    $2,270.36                            $2,255.98
# 42232                    $1,592.57                            $1,582.50
# 42233                    $1,603.89                            $1,593.74
# 42234                    $2,248.89                            $2,234.65
# 42235                    $1,877.75                            $1,865.87
#
#       individual+3_or_more_children_age_30  \
# 0                                $1,848.00
# 1                                $1,964.00
# 2                                $1,300.00
# 3                                $1,937.00
# 4                                $1,345.00
# ...                                    ...
# 42231                            $2,348.41
# 42232                            $1,647.33
# 42233                            $1,659.04
# 42234                            $2,326.21
# 42235                            $1,942.32
#
#       individual+3_or_more_children_age_40  \
# 0                                $1,925.00
# 1                                $2,046.00
# 2                                $1,354.00
# 3                                $2,017.00
# 4                                $1,401.00
# ...                                    ...
# 42231                            $2,446.32
# 42232                            $1,716.01
# 42233                            $1,728.21
# 42234                            $2,423.19
# 42235                            $2,023.29
#
#       individual+3_or_more_children_age_50 standard_plan_cost_sharing  \
# 0                                $2,199.00                        NaN
# 1                                $2,336.00                        NaN
# 2                                $1,547.00                        NaN
# 3                                $2,304.00                        NaN
# 4                                $1,600.00                        NaN
# ...                                    ...                        ...
# 42231                            $2,794.13                        NaN
# 42232                            $1,959.98                        NaN
# 42233                            $1,973.91                        NaN
# 42234                            $2,767.71                        NaN
# 42235                            $2,310.95                        NaN
#
#       medical_deductible_individual_standard  \
# 0                                     $1,500
# 1                                     $4,500
# 2                                     $6,350
# 3                                     $3,000
# 4                                     $5,250
# ...                                      ...
# 42231                                 $3,000
# 42232                                 $6,000
# 42233                                 $7,900
# 42234                                 $6,000
# 42235                                 $2,000
#
#       medical_deductible_family_standard  \
# 0                                 $3,000
# 1                                 $9,000
# 2                                $12,700
# 3                                 $6,000
# 4                                $10,500
# ...                                  ...
# 42231                             $6,000
# 42232                            $12,000
# 42233                            $15,800
# 42234                            $12,000
# 42235                             $4,000
#
#       medical_maximum_out_of_pocket_individual_standard  \
# 0                                                $6,000
# 1                                                $7,350
# 2                                                $7,800
# 3                                                $6,600
# 4                                                $6,700
# ...                                                 ...
# 42231                                            $7,900
# 42232                                            $7,900
# 42233                                            $7,900
# 42234                                            $7,900
# 42235                                            $7,900
#
#       medical_maximum_out_of_pocket_family_standard
# 0                                           $12,000
# 1                                           $14,700
# 2                                           $15,600
# 3                                           $13,200
# 4                                           $13,400
# ...                                             ...
# 42231                                       $15,800
# 42232                                       $15,800
# 42233                                       $15,800
# 42234                                       $15,800
# 42235                                       $15,800
#
# [42236 rows x 49 columns]

# %%
#df['plan_id'] = df['plan_id'].astype('category')

# %%
full_states = {'AK':'Alaska', 'AL':'Alabama', 'AR': 'Arkansas', 'AZ':'Arizona', 'DE': 'Delaware', 'FL':'Florida',
              'GA': 'Georgia', 'HI': 'Hawaii', 'IA': 'Iowa', 'IL': 'Illinois', 'IN': 'Indiana', 'KS': 'Kansas',
              'KY':'Kentucky', 'LA': 'Louisianna', 'ME': 'Maine', 'MI': 'Michigan', 'MO':'Missouri',
               'MS': 'Mississippi', 'MT': 'Montana', 'NC':'North Carolina', 'ND':'North Dakota', 'NE': 'Nebraska',
              'NH':'New Hampshire', 'NJ':'New Jersey', 'NM':'New Mexico', 'NV': 'Nevada', 'OH': 'Ohio', 'OK':'Oklahoma',
              'OR':'Oregon', 'PA':'Pennsylvania', 'SC':'South Carolina', 'SD':'South Dakota', 'TN':'Tennessee',
              'TX':'Texas', 'UT':'Utah','VA':'Virginia', 'WI':'Wisconsin', 'WV':'West Virginia', 'WY':'Wyoming'}

df['state'] = df['state'].replace(full_states)#.astype('category')

# %%
states_list = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'District of Columbia',
               'Delaware',
              'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Louisiana', 'Maine',
              'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska',
              'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 
              'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
              'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']
for state in states_list:
    if state not in df.state.unique():
        print(state)
# Out:
# California
# Colorado
# Connecticut
# District of Columbia
# Idaho
# Louisiana
# Maryland
# Massachusetts
# Minnesota
# New York
# Rhode Island
# Vermont
# Washington

# %%
df.dtypes
# Out:
# plan_id                                               object
# state                                                 object
# metal_level                                           object
# issuer_name                                           object
# plan_marketing_name                                   object
# plan_type                                             object
# ehb_percent_of_total_premium                          object
# premium_child_age_0-14                                object
# premium_child_age_18                                  object
# premium_adult_individual_age_21                       object
# premium_adult_individual_age_27                       object
# premium_adult_individual_age_30_                      object
# premium_adult_individual_age_40_                      object
# premium_adult_individual_age_50_                      object
# premium_adult_individual_age_60_                      object
# premium_couple_21__                                   object
# premium_couple_30_                                    object
# premium_couple_40_                                    object
# premium_couple_50_                                    object
# premium_couple_60_                                    object
# couple+1_child_age_21                                 object
# couple+1_child_age_30_                                object
# couple+1_child_age_40_                                object
# couple+1_child_age_50_                                object
# couple+2_children_age_21                              object
# couple+2_children_age_30_                             object
# couple+2_children_age_40_                             object
# couple+2_children_age_50                              object
# couple+3_or_more_children_age_21                      object
# couple+3_or_more_children_age_30                      object
# couple+3_or_more_children_age_40                      object
# couple+3_or_more_children_age_50                      object
# individual+1_child_age_21                             object
# individual+1_child_age_30                             object
# individual+1_child_age_40                             object
# individual+1_child_age_50                             object
# individual+2_children_age_21                          object
# individual+2_children_age_30                          object
# individual+2_children_age_40                          object
# individual+2_children_age_50                          object
# individual+3_or_more_children_age_21                  object
# individual+3_or_more_children_age_30                  object
# individual+3_or_more_children_age_40                  object
# individual+3_or_more_children_age_50                  object
# standard_plan_cost_sharing                           float64
# medical_deductible_individual_standard                object
# medical_deductible_family_standard                    object
# medical_maximum_out_of_pocket_individual_standard     object
# medical_maximum_out_of_pocket_family_standard         object
# dtype: object

# %%
#for column in (df.columns.to_list())[:6]:
    #df[column] = df[column].astype('category')
for column in (df.columns.to_list())[6:]:
    df[column] = df[column].apply(insert_nan)
    df[column] = df[column].apply(string_to_float)

# %%
# Dropping standard_plan_cost_sharing because it's all NaN values
df = df.drop(columns = "standard_plan_cost_sharing")

# %%
df
# Out:
#               plan_id    state metal_level  \
# 0      38344AK1060001   Alaska        Gold
# 1      38344AK1060002   Alaska      Silver
# 2      38344AK1060004   Alaska      Bronze
# 3      38344AK1070001   Alaska      Silver
# 4      38344AK1070002   Alaska      Bronze
# ...               ...      ...         ...
# 42231  11269WY0070018  Wyoming      Silver
# 42232  11269WY0070019  Wyoming      Bronze
# 42233  11269WY0070022  Wyoming      Bronze
# 42234  11269WY0070023  Wyoming      Silver
# 42235  11269WY0070024  Wyoming        Gold
#
#                                     issuer_name  \
# 0      Premera Blue Cross Blue Shield of Alaska
# 1      Premera Blue Cross Blue Shield of Alaska
# 2      Premera Blue Cross Blue Shield of Alaska
# 3      Premera Blue Cross Blue Shield of Alaska
# 4      Premera Blue Cross Blue Shield of Alaska
# ...                                         ...
# 42231         Blue Cross Blue Shield of Wyoming
# 42232         Blue Cross Blue Shield of Wyoming
# 42233         Blue Cross Blue Shield of Wyoming
# 42234         Blue Cross Blue Shield of Wyoming
# 42235         Blue Cross Blue Shield of Wyoming
#
#                                 plan_marketing_name plan_type  \
# 0            Premera Blue Cross Preferred Gold 1500       PPO
# 1          Premera Blue Cross Preferred Silver 4500       PPO
# 2          Premera Blue Cross Preferred Bronze 6350       PPO
# 3      Premera Blue Cross Preferred Silver 3000 HSA       PPO
# 4      Premera Blue Cross Preferred Bronze 5250 HSA       PPO
# ...                                             ...       ...
# 42231                       BlueSelect Silver Value       PPO
# 42232                       BlueSelect Bronze Value       PPO
# 42233                     BlueSelect Bronze Balance       PPO
# 42234                     BlueSelect Silver Balance       PPO
# 42235                       BlueSelect Gold Balance       PPO
#
#        ehb_percent_of_total_premium  premium_child_age_0-14  \
# 0                              97.2                  412.00
# 1                              97.4                  438.00
# 2                              95.9                  290.00
# 3                              99.9                  432.00
# 4                              99.8                  300.00
# ...                             ...                     ...
# 42231                         100.0                  523.77
# 42232                         100.0                  367.41
# 42233                         100.0                  370.02
# 42234                         100.0                  518.82
# 42235                         100.0                  433.20
#
#        premium_child_age_18  premium_adult_individual_age_21  ...  \
# 0                    492.00                           539.00  ...
# 1                    523.00                           572.00  ...
# 2                    346.00                           379.00  ...
# 3                    515.00                           564.00  ...
# 4                    358.00                           392.00  ...
# ...                     ...                              ...  ...
# 42231                625.11                           684.67  ...
# 42232                438.48                           480.27  ...
# 42233                441.60                           483.68  ...
# 42234                619.19                           678.19  ...
# 42235                517.00                           566.27  ...
#
#        individual+2_children_age_40  individual+2_children_age_50  \
# 0                           1513.00                       1787.00
# 1                           1608.00                       1898.00
# 2                           1064.00                       1257.00
# 3                           1585.00                       1872.00
# 4                           1101.00                       1300.00
# ...                             ...                           ...
# 42231                       1922.55                       2270.36
# 42232                       1348.60                       1592.57
# 42233                       1358.19                       1603.89
# 42234                       1904.37                       2248.89
# 42235                       1590.09                       1877.75
#
#        individual+3_or_more_children_age_21  \
# 0                                   1775.00
# 1                                   1886.00
# 2                                   1249.00
# 3                                   1860.00
# 4                                   1292.00
# ...                                     ...
# 42231                               2255.98
# 42232                               1582.50
# 42233                               1593.74
# 42234                               2234.65
# 42235                               1865.87
#
#        individual+3_or_more_children_age_30  \
# 0                                   1848.00
# 1                                   1964.00
# 2                                   1300.00
# 3                                   1937.00
# 4                                   1345.00
# ...                                     ...
# 42231                               2348.41
# 42232                               1647.33
# 42233                               1659.04
# 42234                               2326.21
# 42235                               1942.32
#
#        individual+3_or_more_children_age_40  \
# 0                                   1925.00
# 1                                   2046.00
# 2                                   1354.00
# 3                                   2017.00
# 4                                   1401.00
# ...                                     ...
# 42231                               2446.32
# 42232                               1716.01
# 42233                               1728.21
# 42234                               2423.19
# 42235                               2023.29
#
#        individual+3_or_more_children_age_50  \
# 0                                   2199.00
# 1                                   2336.00
# 2                                   1547.00
# 3                                   2304.00
# 4                                   1600.00
# ...                                     ...
# 42231                               2794.13
# 42232                               1959.98
# 42233                               1973.91
# 42234                               2767.71
# 42235                               2310.95
#
#        medical_deductible_individual_standard  \
# 0                                      1500.0
# 1                                      4500.0
# 2                                      6350.0
# 3                                      3000.0
# 4                                      5250.0
# ...                                       ...
# 42231                                  3000.0
# 42232                                  6000.0
# 42233                                  7900.0
# 42234                                  6000.0
# 42235                                  2000.0
#
#        medical_deductible_family_standard  \
# 0                                  3000.0
# 1                                  9000.0
# 2                                 12700.0
# 3                                  6000.0
# 4                                 10500.0
# ...                                   ...
# 42231                              6000.0
# 42232                             12000.0
# 42233                             15800.0
# 42234                             12000.0
# 42235                              4000.0
#
#        medical_maximum_out_of_pocket_individual_standard  \
# 0                                                 6000.0
# 1                                                 7350.0
# 2                                                 7800.0
# 3                                                 6600.0
# 4                                                 6700.0
# ...                                                  ...
# 42231                                             7900.0
# 42232                                             7900.0
# 42233                                             7900.0
# 42234                                             7900.0
# 42235                                             7900.0
#
#        medical_maximum_out_of_pocket_family_standard
# 0                                            12000.0
# 1                                            14700.0
# 2                                            15600.0
# 3                                            13200.0
# 4                                            13400.0
# ...                                              ...
# 42231                                        15800.0
# 42232                                        15800.0
# 42233                                        15800.0
# 42234                                        15800.0
# 42235                                        15800.0
#
# [42236 rows x 48 columns]

# %%
# Remove Outliers for df
for state in df.state.unique().tolist():
    temp_df = df[df.state==state]
    Q1 = temp_df.quantile(0.25)
    Q3 = temp_df.quantile(0.75)
    IQR = Q3 - Q1
    
    #temp_df_in = temp_df[((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
    print(temp_df)
    temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
    #print(temp_df_in)
    
    df[df.state==state] = temp_df_out

df = df.dropna(subset='state')
# Out:
#             plan_id   state metal_level  \
# 0    38344AK1060001  Alaska        Gold
# 1    38344AK1060002  Alaska      Silver
# 2    38344AK1060004  Alaska      Bronze
# 3    38344AK1070001  Alaska      Silver
# 4    38344AK1070002  Alaska      Bronze
# ..              ...     ...         ...
# 140  38344AK1060001  Alaska        Gold
# 141  38344AK1060002  Alaska      Silver
# 142  38344AK1060004  Alaska      Bronze
# 143  38344AK1070001  Alaska      Silver
# 144  38344AK1070002  Alaska      Bronze
#
#                                   issuer_name  \
# 0    Premera Blue Cross Blue Shield of Alaska
# 1    Premera Blue Cross Blue Shield of Alaska
# 2    Premera Blue Cross Blue Shield of Alaska
# 3    Premera Blue Cross Blue Shield of Alaska
# 4    Premera Blue Cross Blue Shield of Alaska
# ..                                        ...
# 140  Premera Blue Cross Blue Shield of Alaska
# 141  Premera Blue Cross Blue Shield of Alaska
# 142  Premera Blue Cross Blue Shield of Alaska
# 143  Premera Blue Cross Blue Shield of Alaska
# 144  Premera Blue Cross Blue Shield of Alaska
#
#                               plan_marketing_name plan_type  \
# 0          Premera Blue Cross Preferred Gold 1500       PPO
# 1        Premera Blue Cross Preferred Silver 4500       PPO
# 2        Premera Blue Cross Preferred Bronze 6350       PPO
# 3    Premera Blue Cross Preferred Silver 3000 HSA       PPO
# 4    Premera Blue Cross Preferred Bronze 5250 HSA       PPO
# ..                                            ...       ...
# 140        Premera Blue Cross Preferred Gold 1500       PPO
# 141      Premera Blue Cross Preferred Silver 4500       PPO
# 142      Premera Blue Cross Preferred Bronze 6350       PPO
# 143  Premera Blue Cross Preferred Silver 3000 HSA       PPO
# 144  Premera Blue Cross Preferred Bronze 5250 HSA       PPO
#
#      ehb_percent_of_total_premium  premium_child_age_0-14  \
# 0                            97.2                   412.0
# 1                            97.4                   438.0
# 2                            95.9                   290.0
# 3                            99.9                   432.0
# 4                            99.8                   300.0
# ..                            ...                     ...
# 140                          97.2                   412.0
# 141                          97.4                   438.0
# 142                          95.9                   290.0
# 143                          99.9                   432.0
# 144                          99.8                   300.0
#
#      premium_child_age_18  premium_adult_individual_age_21  ...  \
# 0                   492.0                            539.0  ...
# 1                   523.0                            572.0  ...
# 2                   346.0                            379.0  ...
# 3                   515.0                            564.0  ...
# 4                   358.0                            392.0  ...
# ..                    ...                              ...  ...
# 140                 492.0                            539.0  ...
# 141                 523.0                            572.0  ...
# 142                 346.0                            379.0  ...
# 143                 515.0                            564.0  ...
# 144                 358.0                            392.0  ...
#
#      individual+2_children_age_40  individual+2_children_age_50  \
# 0                          1513.0                        1787.0
# 1                          1608.0                        1898.0
# 2                          1064.0                        1257.0
# 3                          1585.0                        1872.0
# 4                          1101.0                        1300.0
# ..                            ...                           ...
# 140                        1513.0                        1787.0
# 141                        1608.0                        1898.0
# 142                        1064.0                        1257.0
# 143                        1585.0                        1872.0
# 144                        1101.0                        1300.0
#
#      individual+3_or_more_children_age_21  \
# 0                                  1775.0
# 1                                  1886.0
# 2                                  1249.0
# 3                                  1860.0
# 4                                  1292.0
# ..                                    ...
# 140                                1775.0
# 141                                1886.0
# 142                                1249.0
# 143                                1860.0
# 144                                1292.0
#
#      individual+3_or_more_children_age_30  \
# 0                                  1848.0
# 1                                  1964.0
# 2                                  1300.0
# 3                                  1937.0
# 4                                  1345.0
# ..                                    ...
# 140                                1848.0
# 141                                1964.0
# 142                                1300.0
# 143                                1937.0
# 144                                1345.0
#
#      individual+3_or_more_children_age_40  \
# 0                                  1925.0
# 1                                  2046.0
# 2                                  1354.0
# 3                                  2017.0
# 4                                  1401.0
# ..                                    ...
# 140                                1925.0
# 141                                2046.0
# 142                                1354.0
# 143                                2017.0
# 144                                1401.0
#
#      individual+3_or_more_children_age_50  \
# 0                                  2199.0
# 1                                  2336.0
# 2                                  1547.0
# 3                                  2304.0
# 4                                  1600.0
# ..                                    ...
# 140                                2199.0
# 141                                2336.0
# 142                                1547.0
# 143                                2304.0
# 144                                1600.0
#
#      medical_deductible_individual_standard  \
# 0                                    1500.0
# 1                                    4500.0
# 2                                    6350.0
# 3                                    3000.0
# 4                                    5250.0
# ..                                      ...
# 140                                  1500.0
# 141                                  4500.0
# 142                                  6350.0
# 143                                  3000.0
# 144                                  5250.0
#
#      medical_deductible_family_standard  \
# 0                                3000.0
# 1                                9000.0
# 2                               12700.0
# 3                                6000.0
# 4                               10500.0
# ..                                  ...
# 140                              3000.0
# 141                              9000.0
# 142                             12700.0
# 143                              6000.0
# 144                             10500.0
#
#      medical_maximum_out_of_pocket_individual_standard  \
# 0                                               6000.0
# 1                                               7350.0
# 2                                               7800.0
# 3                                               6600.0
# 4                                               6700.0
# ..                                                 ...
# 140                                             6000.0
# 141                                             7350.0
# 142                                             7800.0
# 143                                             6600.0
# 144                                             6700.0
#
#      medical_maximum_out_of_pocket_family_standard
# 0                                          12000.0
# 1                                          14700.0
# 2                                          15600.0
# 3                                          13200.0
# 4                                          13400.0
# ..                                             ...
# 140                                        12000.0
# 141                                        14700.0
# 142                                        15600.0
# 143                                        13200.0
# 144                                        13400.0
#
# [145 rows x 48 columns]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
#             plan_id    state      metal_level  \
# 145  46944AL0370001  Alabama             Gold
# 146  46944AL0410001  Alabama           Silver
# 147  46944AL0460001  Alabama  Expanded Bronze
# 148  46944AL0470001  Alabama     Catastrophic
# 149  46944AL0560001  Alabama  Expanded Bronze
# ..              ...      ...              ...
# 627  46944AL0460001  Alabama  Expanded Bronze
# 628  46944AL0470001  Alabama     Catastrophic
# 629  46944AL0560001  Alabama  Expanded Bronze
# 630  46944AL0650001  Alabama             Gold
# 631  46944AL0660001  Alabama           Silver
#
#                                issuer_name       plan_marketing_name  \
# 145  Blue Cross and Blue Shield of Alabama           Blue Value Gold
# 146  Blue Cross and Blue Shield of Alabama         Blue Value Silver
# 147  Blue Cross and Blue Shield of Alabama         Blue Saver Bronze
# 148  Blue Cross and Blue Shield of Alabama              Blue Protect
# 149  Blue Cross and Blue Shield of Alabama           Blue HSA Bronze
# ..                                     ...                       ...
# 627  Blue Cross and Blue Shield of Alabama         Blue Saver Bronze
# 628  Blue Cross and Blue Shield of Alabama              Blue Protect
# 629  Blue Cross and Blue Shield of Alabama           Blue HSA Bronze
# 630  Blue Cross and Blue Shield of Alabama    Blue Cross Select Gold
# 631  Blue Cross and Blue Shield of Alabama  Blue Cross Select Silver
#
#     plan_type  ehb_percent_of_total_premium  premium_child_age_0-14  \
# 145       PPO                         100.0                  319.81
# 146       PPO                         100.0                  283.96
# 147       PPO                         100.0                  188.56
# 148       PPO                         100.0                  153.06
# 149       PPO                         100.0                  188.02
# ..        ...                           ...                     ...
# 627       PPO                         100.0                  177.25
# 628       PPO                         100.0                  143.88
# 629       PPO                         100.0                  176.74
# 630       PPO                         100.0                  288.46
# 631       PPO                         100.0                  245.33
#
#      premium_child_age_18  premium_adult_individual_age_21  ...  \
# 145                319.81                           503.64  ...
# 146                283.96                           447.18  ...
# 147                188.56                           296.95  ...
# 148                153.06                           241.04  ...
# 149                188.02                           296.09  ...
# ..                    ...                              ...  ...
# 627                177.25                           279.13  ...
# 628                143.88                           226.58  ...
# 629                176.74                           278.32  ...
# 630                288.46                           454.26  ...
# 631                245.33                           386.34  ...
#
#      individual+2_children_age_40  individual+2_children_age_50  \
# 145                       1283.27                       1539.12
# 146                       1139.42                       1366.58
# 147                        756.62                        907.47
# 148                        614.17                        736.62
# 149                        754.44                        904.86
# ..                            ...                           ...
# 627                        711.23                        853.03
# 628                        577.33                        692.43
# 629                        709.18                        850.57
# 630                       1157.47                       1388.24
# 631                        984.40                       1180.66
#
#      individual+3_or_more_children_age_21  \
# 145                               1463.07
# 146                               1299.06
# 147                                862.63
# 148                                700.22
# 149                                860.15
# ..                                    ...
# 627                                810.88
# 628                                658.22
# 629                                808.54
# 630                               1319.64
# 631                               1122.33
#
#      individual+3_or_more_children_age_30  \
# 145                               1531.06
# 146                               1359.43
# 147                                902.72
# 148                                732.76
# 149                                900.12
# ..                                    ...
# 627                                848.57
# 628                                688.81
# 629                                846.12
# 630                               1380.97
# 631                               1174.49
#
#      individual+3_or_more_children_age_40  \
# 145                               1603.08
# 146                               1423.38
# 147                                945.18
# 148                                767.23
# 149                                942.46
# ..                                    ...
# 627                                888.48
# 628                                721.21
# 629                                885.92
# 630                               1445.93
# 631                               1229.73
#
#      individual+3_or_more_children_age_50  \
# 145                               1858.93
# 146                               1650.54
# 147                               1096.03
# 148                                889.68
# 149                               1092.88
# ..                                    ...
# 627                               1030.28
# 628                                836.31
# 629                               1027.31
# 630                               1676.70
# 631                               1425.99
#
#      medical_deductible_individual_standard  \
# 145                                   750.0
# 146                                  2600.0
# 147                                  7150.0
# 148                                  7900.0
# 149                                  6450.0
# ..                                      ...
# 627                                  7150.0
# 628                                  7900.0
# 629                                  6450.0
# 630                                   850.0
# 631                                  2800.0
#
#      medical_deductible_family_standard  \
# 145                              1500.0
# 146                              5200.0
# 147                             14300.0
# 148                             15800.0
# 149                             12900.0
# ..                                  ...
# 627                             14300.0
# 628                             15800.0
# 629                             12900.0
# 630                              1700.0
# 631                              5600.0
#
#      medical_maximum_out_of_pocket_individual_standard  \
# 145                                             6000.0
# 146                                             7900.0
# 147                                             7150.0
# 148                                             7900.0
# 149                                             6450.0
# ..                                                 ...
# 627                                             7150.0
# 628                                             7900.0
# 629                                             6450.0
# 630                                             6000.0
# 631                                             7900.0
#
#      medical_maximum_out_of_pocket_family_standard
# 145                                        12000.0
# 146                                        15800.0
# 147                                        14300.0
# 148                                        15800.0
# 149                                        12900.0
# ..                                             ...
# 627                                        14300.0
# 628                                        15800.0
# 629                                        12900.0
# 630                                        12000.0
# 631                                        15800.0
#
# [487 rows x 48 columns]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
#              plan_id     state      metal_level  \
# 632   37903AR0070001  Arkansas           Silver
# 634   37903AR0070015  Arkansas           Silver
# 636   62141AR0080005  Arkansas           Bronze
# 637   62141AR0080007  Arkansas           Silver
# 638   62141AR0080008  Arkansas           Silver
# ...              ...       ...              ...
# 2428  75293AR1200006  Arkansas           Silver
# 2429  75293AR1200007  Arkansas  Expanded Bronze
# 2431  75293AR1200014  Arkansas           Silver
# 2432  75293AR1200021  Arkansas           Silver
# 2433  75293AR1210002  Arkansas           Silver
#
#                                            issuer_name  \
# 632   QualChoice Life & Health Insurance Company, Inc.
# 634   QualChoice Life & Health Insurance Company, Inc.
# 636                           Celtic Insurance Company
# 637                           Celtic Insurance Company
# 638                           Celtic Insurance Company
# ...                                                ...
# 2428                   USAble Mutual Insurance Company
# 2429                   USAble Mutual Insurance Company
# 2431                   USAble Mutual Insurance Company
# 2432                   USAble Mutual Insurance Company
# 2433                   USAble Mutual Insurance Company
#
#                    plan_marketing_name plan_type  \
# 632                        Silver 6500       PPO
# 634                  Silver Saver 4000       PPO
# 636   Ambetter Essential Care 6 (2019)       PPO
# 637    Ambetter Balanced Care 7 (2019)       PPO
# 638    Ambetter Balanced Care 6 (2019)       PPO
# ...                                ...       ...
# 2428                  Silver Plan HSA1       PPO
# 2429                     Bronze Plan 1       PPO
# 2431                     Silver Plan 2       PPO
# 2432                     Silver Plan 4       PPO
# 2433                  Silver Plan AWM1       PPO
#
#       ehb_percent_of_total_premium  premium_child_age_0-14  \
# 632                         100.00                  246.56
# 634                         100.00                  246.56
# 636                         100.00                  200.93
# 637                         100.00                  237.79
# 638                         100.00                  233.27
# ...                            ...                     ...
# 2428                         99.59                  237.67
# 2429                         99.59                  196.03
# 2431                         99.59                  227.86
# 2432                         99.59                  228.00
# 2433                         99.85                  231.17
#
#       premium_child_age_18  premium_adult_individual_age_21  ...  \
# 632                 294.26                           322.30  ...
# 634                 294.26                           322.30  ...
# 636                 239.81                           262.67  ...
# 637                 283.79                           310.85  ...
# 638                 278.40                           304.94  ...
# ...                    ...                              ...  ...
# 2428                283.65                           310.68  ...
# 2429                233.96                           256.25  ...
# 2431                271.95                           297.86  ...
# 2432                272.11                           298.04  ...
# 2433                275.89                           302.18  ...
#
#       individual+2_children_age_40  individual+2_children_age_50  \
# 632                         905.01                       1068.74
# 634                         905.01                       1068.74
# 636                         737.53                        870.96
# 637                         872.83                       1030.73
# 638                         856.24                       1011.14
# ...                            ...                           ...
# 2428                        872.39                       1030.21
# 2429                        719.55                        849.72
# 2431                        836.39                        987.70
# 2432                        836.90                        988.30
# 2433                        848.53                       1002.03
#
#       individual+3_or_more_children_age_21  \
# 632                                1061.98
# 634                                1061.98
# 636                                 865.46
# 637                                1024.22
# 638                                1004.75
# ...                                    ...
# 2428                               1023.69
# 2429                                844.34
# 2431                                981.44
# 2432                                982.04
# 2433                                995.69
#
#       individual+3_or_more_children_age_30  \
# 632                                1105.49
# 634                                1105.49
# 636                                 900.90
# 637                                1066.17
# 638                                1045.91
# ...                                    ...
# 2428                               1065.63
# 2429                                878.93
# 2431                               1021.65
# 2432                               1022.28
# 2433                               1036.48
#
#       individual+3_or_more_children_age_40  \
# 632                                1151.57
# 634                                1151.57
# 636                                 938.46
# 637                                1110.62
# 638                                1089.51
# ...                                    ...
# 2428                               1110.06
# 2429                                915.58
# 2431                               1064.25
# 2432                               1064.90
# 2433                               1079.70
#
#       individual+3_or_more_children_age_50  \
# 632                                1315.30
# 634                                1315.30
# 636                                1071.89
# 637                                1268.52
# 638                                1244.41
# ...                                    ...
# 2428                               1267.88
# 2429                               1045.75
# 2431                               1215.56
# 2432                               1216.30
# 2433                               1233.20
#
#       medical_deductible_individual_standard  \
# 632                                   6500.0
# 634                                   4000.0
# 636                                   5650.0
# 637                                   5100.0
# 638                                   3000.0
# ...                                      ...
# 2428                                  3600.0
# 2429                                  6600.0
# 2431                                  5000.0
# 2432                                  5250.0
# 2433                                  2650.0
#
#       medical_deductible_family_standard  \
# 632                              13000.0
# 634                               8000.0
# 636                              11300.0
# 637                              10200.0
# 638                               6000.0
# ...                                  ...
# 2428                              7200.0
# 2429                             13200.0
# 2431                             10000.0
# 2432                             10500.0
# 2433                              5300.0
#
#       medical_maximum_out_of_pocket_individual_standard  \
# 632                                              7350.0
# 634                                              5250.0
# 636                                              7650.0
# 637                                              6450.0
# 638                                              6750.0
# ...                                                 ...
# 2428                                             6650.0
# 2429                                             7900.0
# 2431                                             7900.0
# 2432                                             7900.0
# 2433                                             7900.0
#
#       medical_maximum_out_of_pocket_family_standard
# 632                                         14700.0
# 634                                         10500.0
# 636                                         15300.0
# 637                                         12900.0
# 638                                         13500.0
# ...                                             ...
# 2428                                        13300.0
# 2429                                        15800.0
# 2431                                        15800.0
# 2432                                        15800.0
# 2433                                        15800.0
#
# [1252 rows x 48 columns]
# Empty DataFrame
# Columns: [plan_id, state, metal_level, issuer_name, plan_marketing_name, plan_type, ehb_percent_of_total_premium, premium_child_age_0-14, premium_child_age_18, premium_adult_individual_age_21, premium_adult_individual_age_27, premium_adult_individual_age_30_, premium_adult_individual_age_40_, premium_adult_individual_age_50_, premium_adult_individual_age_60_, premium_couple_21__, premium_couple_30_, premium_couple_40_, premium_couple_50_, premium_couple_60_, couple+1_child_age_21, couple+1_child_age_30_, couple+1_child_age_40_, couple+1_child_age_50_, couple+2_children_age_21, couple+2_children_age_30_, couple+2_children_age_40_, couple+2_children_age_50, couple+3_or_more_children_age_21, couple+3_or_more_children_age_30, couple+3_or_more_children_age_40, couple+3_or_more_children_age_50, individual+1_child_age_21, individual+1_child_age_30, individual+1_child_age_40, individual+1_child_age_50, individual+2_children_age_21, individual+2_children_age_30, individual+2_children_age_40, individual+2_children_age_50, individual+3_or_more_children_age_21, individual+3_or_more_children_age_30, individual+3_or_more_children_age_40, individual+3_or_more_children_age_50, medical_deductible_individual_standard, medical_deductible_family_standard, medical_maximum_out_of_pocket_individual_standard, medical_maximum_out_of_pocket_family_standard]
# Index: []
#
# [0 rows x 48 columns]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
#              plan_id    state      metal_level  \
# 2435  53901AZ1420045  Arizona           Silver
# 2436  53901AZ1420051  Arizona             Gold
# 2437  53901AZ1420057  Arizona           Silver
# 2438  53901AZ1420063  Arizona  Expanded Bronze
# 2439  53901AZ1420069  Arizona           Bronze
# ...              ...      ...              ...
# 2550  53901AZ1420014  Arizona           Silver
# 2551  53901AZ1420021  Arizona  Expanded Bronze
# 2552  53901AZ1420028  Arizona           Bronze
# 2553  53901AZ1420035  Arizona     Catastrophic
# 2554  53901AZ1420041  Arizona           Silver
#
#                                       issuer_name  \
# 2435  Blue Cross and Blue Shield of Arizona, Inc.
# 2436  Blue Cross and Blue Shield of Arizona, Inc.
# 2437  Blue Cross and Blue Shield of Arizona, Inc.
# 2438  Blue Cross and Blue Shield of Arizona, Inc.
# 2439  Blue Cross and Blue Shield of Arizona, Inc.
# ...                                           ...
# 2550  Blue Cross and Blue Shield of Arizona, Inc.
# 2551  Blue Cross and Blue Shield of Arizona, Inc.
# 2552  Blue Cross and Blue Shield of Arizona, Inc.
# 2553  Blue Cross and Blue Shield of Arizona, Inc.
# 2554  Blue Cross and Blue Shield of Arizona, Inc.
#
#                                  plan_marketing_name plan_type  \
# 2435      TrueHealth HMO 6000 - Neighborhood Network       HMO
# 2436  EverydayHealth HMO 2000 - Neighborhood Network       HMO
# 2437  EverydayHealth HMO 4000 - Neighborhood Network       HMO
# 2438  EverydayHealth HMO 6500 - Neighborhood Network       HMO
# 2439   Portfolio HSA HMO 5850 - Neighborhood Network       HMO
# ...                                              ...       ...
# 2550  EverydayHealth HMO 4000 - Neighborhood Network       HMO
# 2551  EverydayHealth HMO 6500 - Neighborhood Network       HMO
# 2552   Portfolio HSA HMO 5850 - Neighborhood Network       HMO
# 2553         SimpleHealth HMO - Neighborhood Network       HMO
# 2554      TrueHealth HMO 6000 - Neighborhood Network       HMO
#
#       ehb_percent_of_total_premium  premium_child_age_0-14  \
# 2435                         100.0                  388.10
# 2436                         100.0                  458.81
# 2437                         100.0                  411.33
# 2438                         100.0                  313.02
# 2439                         100.0                  301.47
# ...                            ...                     ...
# 2550                         100.0                  438.16
# 2551                         100.0                  333.45
# 2552                         100.0                  321.13
# 2553                         100.0                  283.10
# 2554                         100.0                  413.42
#
#       premium_child_age_18  premium_adult_individual_age_21  ...  \
# 2435                463.19                           507.32  ...
# 2436                547.57                           599.75  ...
# 2437                490.90                           537.68  ...
# 2438                373.58                           409.18  ...
# 2439                359.79                           394.07  ...
# ...                    ...                              ...  ...
# 2550                522.93                           572.76  ...
# 2551                397.95                           435.87  ...
# 2552                383.26                           419.78  ...
# 2553                337.87                           370.07  ...
# 2554                493.40                           540.42  ...
#
#       individual+2_children_age_40  individual+2_children_age_50  \
# 2435                       1424.56                       1682.28
# 2436                       1684.10                       1988.77
# 2437                       1509.82                       1782.96
# 2438                       1148.97                       1356.83
# 2439                       1106.56                       1306.75
# ...                            ...                           ...
# 2550                       1608.30                       1899.26
# 2551                       1223.95                       1445.37
# 2552                       1178.74                       1391.99
# 2553                       1039.15                       1227.14
# 2554                       1517.50                       1792.03
#
#       individual+3_or_more_children_age_21  \
# 2435                               1671.62
# 2436                               1976.18
# 2437                               1771.67
# 2438                               1348.24
# 2439                               1298.48
# ...                                    ...
# 2550                               1887.24
# 2551                               1436.22
# 2552                               1383.17
# 2553                               1219.37
# 2554                               1780.68
#
#       individual+3_or_more_children_age_30  \
# 2435                               1740.11
# 2436                               2057.15
# 2437                               1844.26
# 2438                               1403.48
# 2439                               1351.68
# ...                                    ...
# 2550                               1964.56
# 2551                               1495.07
# 2552                               1439.84
# 2553                               1269.33
# 2554                               1853.64
#
#       individual+3_or_more_children_age_40  \
# 2435                               1812.66
# 2436                               2142.91
# 2437                               1921.15
# 2438                               1461.99
# 2439                               1408.03
# ...                                    ...
# 2550                               2046.46
# 2551                               1557.40
# 2552                               1499.87
# 2553                               1322.25
# 2554                               1930.92
#
#       individual+3_or_more_children_age_50  \
# 2435                               2070.38
# 2436                               2447.58
# 2437                               2194.29
# 2438                               1669.85
# 2439                               1608.22
# ...                                    ...
# 2550                               2337.42
# 2551                               1778.82
# 2552                               1713.12
# 2553                               1510.24
# 2554                               2205.45
#
#       medical_deductible_individual_standard  \
# 2435                                  6000.0
# 2436                                  2000.0
# 2437                                  4000.0
# 2438                                  6500.0
# 2439                                  5850.0
# ...                                      ...
# 2550                                  4000.0
# 2551                                  6500.0
# 2552                                  5850.0
# 2553                                  7900.0
# 2554                                  6000.0
#
#       medical_deductible_family_standard  \
# 2435                             12000.0
# 2436                              4000.0
# 2437                              8000.0
# 2438                             13000.0
# 2439                             11700.0
# ...                                  ...
# 2550                              8000.0
# 2551                             13000.0
# 2552                             11700.0
# 2553                             15800.0
# 2554                             12000.0
#
#       medical_maximum_out_of_pocket_individual_standard  \
# 2435                                             6500.0
# 2436                                             6000.0
# 2437                                             6650.0
# 2438                                             7900.0
# 2439                                             6750.0
# ...                                                 ...
# 2550                                             6650.0
# 2551                                             7900.0
# 2552                                             6750.0
# 2553                                             7900.0
# 2554                                             6500.0
#
#       medical_maximum_out_of_pocket_family_standard
# 2435                                        13000.0
# 2436                                        12000.0
# 2437                                        13300.0
# 2438                                        15800.0
# 2439                                        13500.0
# ...                                             ...
# 2550                                        13300.0
# 2551                                        15800.0
# 2552                                        13500.0
# 2553                                        15800.0
# 2554                                        13000.0
#
# [102 rows x 48 columns]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
#              plan_id     state      metal_level          issuer_name  \
# 2555  76168DE0400001  Delaware     Catastrophic  Highmark BCBSD Inc.
# 2556  76168DE0410010  Delaware  Expanded Bronze  Highmark BCBSD Inc.
# 2557  76168DE0410012  Delaware             Gold  Highmark BCBSD Inc.
# 2558  76168DE0410013  Delaware           Silver  Highmark BCBSD Inc.
# 2559  76168DE0410018  Delaware           Bronze  Highmark BCBSD Inc.
# 2560  76168DE0410020  Delaware           Silver  Highmark BCBSD Inc.
# 2561  76168DE0410021  Delaware         Platinum  Highmark BCBSD Inc.
# 2562  76168DE0420004  Delaware           Silver  Highmark BCBSD Inc.
# 2563  76168DE0400001  Delaware     Catastrophic  Highmark BCBSD Inc.
# 2564  76168DE0410010  Delaware  Expanded Bronze  Highmark BCBSD Inc.
# 2565  76168DE0410012  Delaware             Gold  Highmark BCBSD Inc.
# 2566  76168DE0410013  Delaware           Silver  Highmark BCBSD Inc.
# 2567  76168DE0410018  Delaware           Bronze  Highmark BCBSD Inc.
# 2568  76168DE0410020  Delaware           Silver  Highmark BCBSD Inc.
# 2569  76168DE0410021  Delaware         Platinum  Highmark BCBSD Inc.
# 2570  76168DE0420004  Delaware           Silver  Highmark BCBSD Inc.
# 2571  76168DE0400001  Delaware     Catastrophic  Highmark BCBSD Inc.
# 2572  76168DE0410010  Delaware  Expanded Bronze  Highmark BCBSD Inc.
# 2573  76168DE0410012  Delaware             Gold  Highmark BCBSD Inc.
# 2574  76168DE0410013  Delaware           Silver  Highmark BCBSD Inc.
# 2575  76168DE0410018  Delaware           Bronze  Highmark BCBSD Inc.
# 2576  76168DE0410020  Delaware           Silver  Highmark BCBSD Inc.
# 2577  76168DE0410021  Delaware         Platinum  Highmark BCBSD Inc.
# 2578  76168DE0420004  Delaware           Silver  Highmark BCBSD Inc.
#
#                                     plan_marketing_name plan_type  \
# 2555                         Major Events Blue EPO 7900       EPO
# 2556                   Shared Cost Blue EPO Bronze 4000       EPO
# 2557  Shared Cost Blue EPO Gold 1000 - 2 Free PCP Vi...       EPO
# 2558  Shared Cost Blue EPO Silver 2400 - 2 Free PCP ...       EPO
# 2559                   Shared Cost Blue EPO Bronze 7900       EPO
# 2560                      Shared Cost Blue EPO Silver 0       EPO
# 2561  Shared Cost Blue EPO Platinum 200 - 2 Free PCP...       EPO
# 2562   Health Savings Embedded Blue EPO Silver 4450 HSA       EPO
# 2563                         Major Events Blue EPO 7900       EPO
# 2564                   Shared Cost Blue EPO Bronze 4000       EPO
# 2565  Shared Cost Blue EPO Gold 1000 - 2 Free PCP Vi...       EPO
# 2566  Shared Cost Blue EPO Silver 2400 - 2 Free PCP ...       EPO
# 2567                   Shared Cost Blue EPO Bronze 7900       EPO
# 2568                      Shared Cost Blue EPO Silver 0       EPO
# 2569  Shared Cost Blue EPO Platinum 200 - 2 Free PCP...       EPO
# 2570   Health Savings Embedded Blue EPO Silver 4450 HSA       EPO
# 2571                         Major Events Blue EPO 7900       EPO
# 2572                   Shared Cost Blue EPO Bronze 4000       EPO
# 2573  Shared Cost Blue EPO Gold 1000 - 2 Free PCP Vi...       EPO
# 2574  Shared Cost Blue EPO Silver 2400 - 2 Free PCP ...       EPO
# 2575                   Shared Cost Blue EPO Bronze 7900       EPO
# 2576                      Shared Cost Blue EPO Silver 0       EPO
# 2577  Shared Cost Blue EPO Platinum 200 - 2 Free PCP...       EPO
# 2578   Health Savings Embedded Blue EPO Silver 4450 HSA       EPO
#
#       ehb_percent_of_total_premium  premium_child_age_0-14  \
# 2555                         100.0                  233.25
# 2556                         100.0                  286.45
# 2557                         100.0                  402.29
# 2558                         100.0                  409.80
# 2559                         100.0                  268.91
# 2560                         100.0                  427.86
# 2561                         100.0                  467.02
# 2562                         100.0                  395.02
# 2563                         100.0                  233.25
# 2564                         100.0                  286.45
# 2565                         100.0                  402.29
# 2566                         100.0                  409.80
# 2567                         100.0                  268.91
# 2568                         100.0                  427.86
# 2569                         100.0                  467.02
# 2570                         100.0                  395.02
# 2571                         100.0                  233.25
# 2572                         100.0                  286.45
# 2573                         100.0                  402.29
# 2574                         100.0                  409.80
# 2575                         100.0                  268.91
# 2576                         100.0                  427.86
# 2577                         100.0                  467.02
# 2578                         100.0                  395.02
#
#       premium_child_age_18  premium_adult_individual_age_21  ...  \
# 2555                278.37                           304.90  ...
# 2556                341.86                           374.44  ...
# 2557                480.12                           525.87  ...
# 2558                489.08                           535.68  ...
# 2559                320.94                           351.52  ...
# 2560                510.63                           559.29  ...
# 2561                557.37                           610.48  ...
# 2562                471.44                           516.36  ...
# 2563                278.37                           304.90  ...
# 2564                341.86                           374.44  ...
# 2565                480.12                           525.87  ...
# 2566                489.08                           535.68  ...
# 2567                320.94                           351.52  ...
# 2568                510.63                           559.29  ...
# 2569                557.37                           610.48  ...
# 2570                471.44                           516.36  ...
# 2571                278.37                           304.90  ...
# 2572                341.86                           374.44  ...
# 2573                480.12                           525.87  ...
# 2574                489.08                           535.68  ...
# 2575                320.94                           351.52  ...
# 2576                510.63                           559.29  ...
# 2577                557.37                           610.48  ...
# 2578                471.44                           516.36  ...
#
#       individual+2_children_age_40  individual+2_children_age_50  \
# ...
# 41997                               2357.42
# 41998                               1841.71
# 41999                               1639.85
# 42000                               1929.90
#
#        individual+3_or_more_children_age_40  \
# 41236                               1255.13
# 41237                               1478.29
# 41238                               1570.95
# 41239                               1892.90
# 41240                               1983.79
# ...                                     ...
# 41996                               1836.99
# 41997                               2455.70
# 41998                               1918.50
# 41999                               1708.22
# 42000                               2010.36
#
#        individual+3_or_more_children_age_50  \
# 41236                               1433.58
# 41237                               1688.47
# 41238                               1794.30
# 41239                               2162.03
# 41240                               2265.84
# ...                                     ...
# 41996                               2098.17
# 41997                               2804.84
# 41998                               2191.26
# 41999                               1951.09
# 42000                               2296.19
#
#        medical_deductible_individual_standard  \
# 41236                                  7900.0
# 41237                                  7900.0
# 41238                                  4000.0
# 41239                                  2400.0
# 41240                                     0.0
# ...                                       ...
# 41996                                  6400.0
# 41997                                  2000.0
# 41998                                  5700.0
# 41999                                  7400.0
# 42000                                  4400.0
#
#        medical_deductible_family_standard  \
# 41236                             15800.0
# 41237                             15800.0
# 41238                              8000.0
# 41239                              4800.0
# 41240                                 0.0
# ...                                   ...
# 41996                             12800.0
# 41997                              4000.0
# 41998                             11400.0
# 41999                             14800.0
# 42000                              8800.0
#
#        medical_maximum_out_of_pocket_individual_standard  \
# 41236                                             7900.0
# 41237                                             7900.0
# 41238                                             7900.0
# 41239                                             7800.0
# 41240                                             7800.0
# ...                                                  ...
# 41996                                             7900.0
# 41997                                             6500.0
# 41998                                             7700.0
# 41999                                             7900.0
# 42000                                             7500.0
#
#        medical_maximum_out_of_pocket_family_standard
# 41236                                        15800.0
# 41237                                        15800.0
# 41238                                        15800.0
# 41239                                        15600.0
# 41240                                        15600.0
# ...                                              ...
# 41996                                        15800.0
# 41997                                        13000.0
# 41998                                        15400.0
# 41999                                        15800.0
# 42000                                        15000.0
#
# [595 rows x 48 columns]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
#               plan_id    state metal_level                        issuer_name  \
# 42007  11269WY0070011  Wyoming        Gold  Blue Cross Blue Shield of Wyoming
# 42008  11269WY0070013  Wyoming        Gold  Blue Cross Blue Shield of Wyoming
# 42009  11269WY0070014  Wyoming      Silver  Blue Cross Blue Shield of Wyoming
# 42010  11269WY0070016  Wyoming      Silver  Blue Cross Blue Shield of Wyoming
# 42011  11269WY0070018  Wyoming      Silver  Blue Cross Blue Shield of Wyoming
# ...               ...      ...         ...                                ...
# 42231  11269WY0070018  Wyoming      Silver  Blue Cross Blue Shield of Wyoming
# 42232  11269WY0070019  Wyoming      Bronze  Blue Cross Blue Shield of Wyoming
# 42233  11269WY0070022  Wyoming      Bronze  Blue Cross Blue Shield of Wyoming
# 42234  11269WY0070023  Wyoming      Silver  Blue Cross Blue Shield of Wyoming
# 42235  11269WY0070024  Wyoming        Gold  Blue Cross Blue Shield of Wyoming
#
#                 plan_marketing_name plan_type  ehb_percent_of_total_premium  \
# 42007       BlueSelect Gold Classic       PPO                         100.0
# 42008    BlueSelect Gold HealthPlus       PPO                         100.0
# 42009     BlueSelect Silver Classic       PPO                         100.0
# 42010  BlueSelect Silver HealthPlus       PPO                         100.0
# 42011       BlueSelect Silver Value       PPO                         100.0
# ...                             ...       ...                           ...
# 42231       BlueSelect Silver Value       PPO                         100.0
# 42232       BlueSelect Bronze Value       PPO                         100.0
# 42233     BlueSelect Bronze Balance       PPO                         100.0
# 42234     BlueSelect Silver Balance       PPO                         100.0
# 42235       BlueSelect Gold Balance       PPO                         100.0
#
#        premium_child_age_0-14  premium_child_age_18  \
# 42007                  453.39                541.10
# 42008                  453.21                540.88
# 42009                  522.83                623.98
# 42010                  522.69                623.81
# 42011                  523.77                625.11
# ...                       ...                   ...
# 42231                  523.77                625.11
# 42232                  367.41                438.48
# 42233                  370.02                441.60
# 42234                  518.82                619.19
# 42235                  433.20                517.00
#
#        premium_adult_individual_age_21  ...  individual+2_children_age_40  \
# 42007                           592.66  ...                       1664.20
# 42008                           592.42  ...                       1663.54
# 42009                           683.43  ...                       1919.09
# 42010                           683.26  ...                       1918.58
# 42011                           684.67  ...                       1922.55
# ...                                ...  ...                           ...
# 42231                           684.67  ...                       1922.55
# 42232                           480.27  ...                       1348.60
# 42233                           483.68  ...                       1358.19
# 42234                           678.19  ...                       1904.37
# 42235                           566.27  ...                       1590.09
#
#        individual+2_children_age_50  individual+3_or_more_children_age_21  \
# 42007                       1965.27                               1952.83
# 42008                       1964.49                               1952.05
# 42009                       2266.27                               2251.92
# 42010                       2265.67                               2251.33
# 42011                       2270.36                               2255.98
# ...                             ...                                   ...
# 42231                       2270.36                               2255.98
# 42232                       1592.57                               1582.50
# 42233                       1603.89                               1593.74
# 42234                       2248.89                               2234.65
# 42235                       1877.75                               1865.87
#
#        individual+3_or_more_children_age_30  \
# 42007                               2032.84
# 42008                               2032.03
# 42009                               2344.19
# 42010                               2343.57
# 42011                               2348.41
# ...                                     ...
# 42231                               2348.41
# 42232                               1647.33
# 42233                               1659.04
# 42234                               2326.21
# 42235                               1942.32
#
#        individual+3_or_more_children_age_40  \
# 42007                               2117.59
# 42008                               2116.75
# 42009                               2441.92
# 42010                               2441.27
# 42011                               2446.32
# ...                                     ...
# 42231                               2446.32
# 42232                               1716.01
# 42233                               1728.21
# 42234                               2423.19
# 42235                               2023.29
#
#        individual+3_or_more_children_age_50  \
# 42007                               2418.66
# 42008                               2417.70
# 42009                               2789.10
# 42010                               2788.36
# 42011                               2794.13
# ...                                     ...
# 42231                               2794.13
# 42232                               1959.98
# 42233                               1973.91
# 42234                               2767.71
# 42235                               2310.95
#
#        medical_deductible_individual_standard  \
# 42007                                   750.0
# 42008                                  1000.0
# 42009                                  2500.0
# 42010                                  3500.0
# 42011                                  3000.0
# ...                                       ...
# 42231                                  3000.0
# 42232                                  6000.0
# 42233                                  7900.0
# 42234                                  6000.0
# 42235                                  2000.0
#
#        medical_deductible_family_standard  \
# 42007                              1500.0
# 42008                              2000.0
# 42009                              5000.0
# 42010                              7000.0
# 42011                              6000.0
# ...                                   ...
# 42231                              6000.0
# 42232                             12000.0
# 42233                             15800.0
# 42234                             12000.0
# 42235                              4000.0
#
#        medical_maximum_out_of_pocket_individual_standard  \
# 42007                                             7900.0
# 42008                                             7900.0
# 42009                                             7900.0
# 42010                                             7900.0
# 42011                                             7900.0
# ...                                                  ...
# 42231                                             7900.0
# 42232                                             7900.0
# 42233                                             7900.0
# 42234                                             7900.0
# 42235                                             7900.0
#
#        medical_maximum_out_of_pocket_family_standard
# 42007                                        15800.0
# 42008                                        15800.0
# 42009                                        15800.0
# 42010                                        15800.0
# 42011                                        15800.0
# ...                                              ...
# 42231                                        15800.0
# 42232                                        15800.0
# 42233                                        15800.0
# 42234                                        15800.0
# 42235                                        15800.0
#
# [207 rows x 48 columns]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
# <ipython-input-80-da64e0565487>:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   temp_df_out = temp_df[~((temp_df < (Q1 - 1.5 * IQR)) |(temp_df > (Q3 + 1.5 * IQR))).any(axis=1)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-da64e0565487> in <module>
#      13     df[df.state==state] = temp_df_out
#      14
# ---> 15 df = df.dropna(subset='state')
#      16
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5157         if subset is not None:
#    5158             ax = self._get_axis(agg_axis)
# -> 5159             indices = ax.get_indexer_for(subset)
#    5160             check = indices == -1
#    5161             if check.any():
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_indexer_for(self, target, **kwargs)
#    4959         """
#    4960         if self._index_as_unique:
# -> 4961             return self.get_indexer(target, **kwargs)
#    4962         indexer, _ = self.get_indexer_non_unique(target)
#    4963         return indexer
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3146     ) -> np.ndarray:
#    3147         method = missing.clean_reindex_fill_method(method)
# -> 3148         target = ensure_index(target)
#    3149         if tolerance is not None:
#    3150             tolerance = self._convert_tolerance(tolerance, target)
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5916             index_like = copy_func(index_like)
#    5917
# -> 5918     return Index(index_like)
#    5919
#    5920
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     370
#     371         elif data is None or is_scalar(data):
# --> 372             raise cls._scalar_data_error(data)
#     373         elif hasattr(data, "__array__"):
#     374             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, 'state' was passed

# %%
df[df.state.isnull()]
# Out:
#       plan_id state metal_level issuer_name plan_marketing_name plan_type  \
# 633       NaN   NaN         NaN         NaN                 NaN       NaN
# 635       NaN   NaN         NaN         NaN                 NaN       NaN
# 641       NaN   NaN         NaN         NaN                 NaN       NaN
# 642       NaN   NaN         NaN         NaN                 NaN       NaN
# 646       NaN   NaN         NaN         NaN                 NaN       NaN
# ...       ...   ...         ...         ...                 ...       ...
# 42186     NaN   NaN         NaN         NaN                 NaN       NaN
# 42196     NaN   NaN         NaN         NaN                 NaN       NaN
# 42206     NaN   NaN         NaN         NaN                 NaN       NaN
# 42216     NaN   NaN         NaN         NaN                 NaN       NaN
# 42226     NaN   NaN         NaN         NaN                 NaN       NaN
#
#        ehb_percent_of_total_premium  premium_child_age_0-14  \
# 633                             NaN                     NaN
# 635                             NaN                     NaN
# 641                             NaN                     NaN
# 642                             NaN                     NaN
# 646                             NaN                     NaN
# ...                             ...                     ...
# 42186                           NaN                     NaN
# 42196                           NaN                     NaN
# 42206                           NaN                     NaN
# 42216                           NaN                     NaN
# 42226                           NaN                     NaN
#
#        premium_child_age_18  premium_adult_individual_age_21  ...  \
# 633                     NaN                              NaN  ...
# 635                     NaN                              NaN  ...
# 641                     NaN                              NaN  ...
# 642                     NaN                              NaN  ...
# 646                     NaN                              NaN  ...
# ...                     ...                              ...  ...
# 42186                   NaN                              NaN  ...
# 42196                   NaN                              NaN  ...
# 42206                   NaN                              NaN  ...
# 42216                   NaN                              NaN  ...
# 42226                   NaN                              NaN  ...
#
#        individual+2_children_age_40  individual+2_children_age_50  \
# 633                             NaN                           NaN
# 635                             NaN                           NaN
# 641                             NaN                           NaN
# 642                             NaN                           NaN
# 646                             NaN                           NaN
# ...                             ...                           ...
# 42186                           NaN                           NaN
# 42196                           NaN                           NaN
# 42206                           NaN                           NaN
# 42216                           NaN                           NaN
# 42226                           NaN                           NaN
#
#        individual+3_or_more_children_age_21  \
# 633                                     NaN
# 635                                     NaN
# 641                                     NaN
# 642                                     NaN
# 646                                     NaN
# ...                                     ...
# 42186                                   NaN
# 42196                                   NaN
# 42206                                   NaN
# 42216                                   NaN
# 42226                                   NaN
#
#        individual+3_or_more_children_age_30  \
# 633                                     NaN
# 635                                     NaN
# 641                                     NaN
# 642                                     NaN
# 646                                     NaN
# ...                                     ...
# 42186                                   NaN
# 42196                                   NaN
# 42206                                   NaN
# 42216                                   NaN
# 42226                                   NaN
#
#        individual+3_or_more_children_age_40  \
# 633                                     NaN
# 635                                     NaN
# 641                                     NaN
# 642                                     NaN
# 646                                     NaN
# ...                                     ...
# 42186                                   NaN
# 42196                                   NaN
# 42206                                   NaN
# 42216                                   NaN
# 42226                                   NaN
#
#        individual+3_or_more_children_age_50  \
# 633                                     NaN
# 635                                     NaN
# 641                                     NaN
# 642                                     NaN
# 646                                     NaN
# ...                                     ...
# 42186                                   NaN
# 42196                                   NaN
# 42206                                   NaN
# 42216                                   NaN
# 42226                                   NaN
#
#        medical_deductible_individual_standard  \
# 633                                       NaN
# 635                                       NaN
# 641                                       NaN
# 642                                       NaN
# 646                                       NaN
# ...                                       ...
# 42186                                     NaN
# 42196                                     NaN
# 42206                                     NaN
# 42216                                     NaN
# 42226                                     NaN
#
#        medical_deductible_family_standard  \
# 633                                   NaN
# 635                                   NaN
# 641                                   NaN
# 642                                   NaN
# 646                                   NaN
# ...                                   ...
# 42186                                 NaN
# 42196                                 NaN
# 42206                                 NaN
# 42216                                 NaN
# 42226                                 NaN
#
#        medical_maximum_out_of_pocket_individual_standard  \
# 633                                                  NaN
# 635                                                  NaN
# 641                                                  NaN
# 642                                                  NaN
# 646                                                  NaN
# ...                                                  ...
# 42186                                                NaN
# 42196                                                NaN
# 42206                                                NaN
# 42216                                                NaN
# 42226                                                NaN
#
#        medical_maximum_out_of_pocket_family_standard
# 633                                              NaN
# 635                                              NaN
# 641                                              NaN
# 642                                              NaN
# 646                                              NaN
# ...                                              ...
# 42186                                            NaN
# 42196                                            NaN
# 42206                                            NaN
# 42216                                            NaN
# 42226                                            NaN
#
# [7745 rows x 48 columns]

# %%
df.to_csv('Data/Cleaned_Health_Plans.csv')
