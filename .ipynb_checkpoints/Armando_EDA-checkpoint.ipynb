# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats
from statsmodels.stats.outliers_influence import variance_inflation_factor
from collections import defaultdict
import missingno as msn
import plotly.figure_factory as ff

# %%
# !pip install plotly-geo

# %%
state_list = ['Alabama',
'Alaska',
'Arizona',
'Arkansas',
'California',
'Colorado',
'Connecticut',
'Delaware',
'Florida',
'Georgia',
'Hawaii',
'Idaho',
'Illinois',
'Indiana',
'Iowa',
'Kansas',
'Kentucky',
'Louisiana',
'Maine',
'Maryland',
'Massachusetts',
'Michigan',
'Minnesota',
'Mississippi',
'Missouri',
'Montana', 
'Nebraska',
'Nevada',
'New Hampshire',
'New Jersey',
'New Mexico',
'New York',
'North Carolina',
'North Dakota',
'Ohio',
'Oklahoma',
'Oregon',
'Pennsylvania',
'Rhode Island',
'South Carolina',
'South Dakota',
'Tennessee',
'Texas',
'Utah',
'Vermont',
'Virginia',
'Washington',
'West Virginia',
'Wisconsin',
'Wyoming', 'District of Columbia', 'United States']

# %%
df = pd.read_csv('Data/county_data_clean.csv').drop(columns='Unnamed: 0')

df = df[~(df.name.apply(lambda x: x in state_list))]
df['5_digit_fips_code'] = df['5_digit_fips_code'].apply(lambda x: str(x))

# %%
df.head()
# Out:
#    state_fips_code  county_fips_code 5_digit_fips_code state_abbreviation  \
# 2                1                 1              1001                 AL
# 3                1                 3              1003                 AL
# 4                1                 5              1005                 AL
# 5                1                 7              1007                 AL
# 6                1                 9              1009                 AL
#
#              name  premature_death  premature_death_black  \
# 2  Autauga County      8824.057123           10471.252986
# 3  Baldwin County      7224.632160           10042.472874
# 4  Barbour County      9586.165037           11332.562909
# 5     Bibb County     11783.543675           14812.539280
# 6   Blount County     10908.101822                    NaN
#
#    premature_death_hispanic  premature_death_white  poor_or_fair_health  ...  \
# 2                       NaN            8706.658832             0.184111  ...
# ...

# %%
def correct_fips(fips):
    if len(fips) < 5:
        fips = '0' + fips
    return fips
df['5_digit_fips_code'] = df['5_digit_fips_code'].apply(correct_fips)

# %% [markdown]
# # The first step to take in our EDA was to determine what outliers exist, if any. The code below filters out any outliers within each state's data. No outliers were detected in this scenario, nationwide.
#
# # Source: https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba

# %%
national_df = df.copy()
indep_features_list = df.drop(columns=['uninsured', 'uninsured_adults', 'uninsured_children']).columns.to_list()
print(national_df.shape)


Q1 = national_df[indep_features_list].quantile(0.25)
Q3 = national_df[indep_features_list].quantile(0.75)
IQR = Q3 - Q1
    
national_df[indep_features_list] = national_df[indep_features_list]\
[~((national_df[indep_features_list]< (Q1 - 1.5 * IQR)) |\
(national_df[indep_features_list] > (Q3 + 1.5 * IQR))).any(axis=1)]

national_df.shape
# Out:
# (3141, 156)
# <ipython-input-183-a4b5b484657b>:11: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   [~((national_df[indep_features_list]< (Q1 - 1.5 * IQR)) |\
# <ipython-input-183-a4b5b484657b>:12: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   (national_df[indep_features_list] > (Q3 + 1.5 * IQR))).any(axis=1)]
# (3141, 156)

# %% [markdown]
# The next step to take in our EDA was to determine what outliers exist, if any. The code below filters out any outliers within each state's data. The sample data was at the state level, not nationwide. No outliers were detected in this scenario.
#
#  Source: https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba

# %%
# Looking to see if there are any outliers, looking at each state
print(df.shape)
indep_features_list = df.drop(columns=['uninsured', 'uninsured_adults', 'uninsured_children']).columns.to_list()

for state in df.state_abbreviation.unique():
    Q1 = df[df.state_abbreviation==state][indep_features_list].quantile(0.25)
    Q3 = df[df.state_abbreviation==state][indep_features_list].quantile(0.75)
    IQR = Q3 - Q1
    
    df[df.state_abbreviation==state][indep_features_list] = df[df.state_abbreviation==state][indep_features_list]\
    [~((df[df.state_abbreviation==state][indep_features_list]< (Q1 - 1.5 * IQR)) |\
       (df[df.state_abbreviation==state][indep_features_list] > (Q3 + 1.5 * IQR))).any(axis=1)]


print(df.shape)
# Out:
# (3141, 156)
# <ipython-input-184-42ed80e05937>:11: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   [~((df[df.state_abbreviation==state][indep_features_list]< (Q1 - 1.5 * IQR)) |\
# <ipython-input-184-42ed80e05937>:12: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   (df[df.state_abbreviation==state][indep_features_list] > (Q3 + 1.5 * IQR))).any(axis=1)]
# <ipython-input-184-42ed80e05937>:11: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
# ...

# %% [markdown]
# # Next, we will look at the correlation values that are at least moderately strong (r values are greater than 0.5 or less than -0.5) with the uninsured dependent variable, nationwide.

# %%
# Looking at correlation values, nationwide, and see which independent features have a correlation strong enough for
# further analysis with the uninsured dependent value

corr = df.corr()

for index in corr.index:
    fltr = (corr.loc[index]["uninsured"] >= 0.5) | (corr.loc[index]["uninsured"] <= -0.5)
    if fltr and index not in ['uninsured', 'uninsured_adults', 'uninsured_children']:
        print(index)
        print(corr.loc[index]["uninsured"][fltr])
# Out:
# teen_births
# [0.51921703]
# %_non_hispanic_white
# [-0.50493625]
# childhood_immunizations
# [-0.67202478]
# poverty
# [0.56576628]

# %% [markdown]
# # Now, we have identified the independent variables of interest. The next step  is to see if they are collinear with each other. So, we'll plot a heatmap.

# %%
strong_corr = df[['teen_births', 'childhood_immunizations', 'poverty', '%_non_hispanic_white']].corr()
sns.heatmap(strong_corr, cmap='vlag', annot=True)
plt.savefig("EDA_Visualizations/Heatmaps/national_collinearity", transparent=True, bbox_inches='tight')

# %% [markdown]
# # It seems that there is high correlation, and hence collinearity, between poverty and teen births at the national level. However, these collinearity values should be taken with caution, as the data contains a lot of missing values in these categories, especially with childhood_immunizations and poverty, as shown below.

# %%
print('teen_births')
print(df[~df.teen_births.isnull()]['teen_births'].shape)
print(df['teen_births'].shape)
print("\n")

print('childhood_immunizations')
print(df[~df.childhood_immunizations.isnull()]['childhood_immunizations'].shape)
print(df['childhood_immunizations'].shape)
print("\n")

print('poverty')
print(df[~df.poverty.isnull()]['poverty'].shape)
print(df['poverty'].shape)
print("\n")

print('%_non_hispanic_white')
print(df[~df['%_non_hispanic_white'].isnull()]['%_non_hispanic_white'].shape)
print(df['%_non_hispanic_white'].shape)
print("\n")
# Out:
# teen_births
# (2997,)
# (3141,)
#
#
# childhood_immunizations
# (72,)
# (3141,)
#
#
# poverty
# (72,)
# (3141,)
#
#
# %_non_hispanic_white
# (3141,)
# (3141,)

# %% [markdown]
# # There are three independent variables of interest when it comes to looking at uninsurance rates across the nation: teen_births, childhood_immunizations, and percent_non_hispanic_white. Further exploration by clustering counties across the nation according to a low, medium, or high presence of each variable may reveal interesting insights.
#
# # Before doing that, however, we must see whether the national df is normally distributed, and if the samples' variances are approximately equal to each other. This is in order to see if it is possible to perform an ANOVA test and compare significant differences between low, medium, and high presences for the three variables: teen_births, childhood_immunizations, and percent_non_hispanic_white.
#
# # Because the data is not normally distributed, it is best to use the Kruskal Wallis test instead.
#
# Source: https://www.statology.org/kruskal-wallis-test-python/

# %%
# Checking to see how skewed the df is
def create_histo(df, column_name):
    plt.hist(df[column_name])
    
    plt.ylabel("Frequency")
    plt.xlabel(column_name)
    plt.title(column_name.capitalize() + " distribution")
    plt.show()
    
    plt.savefig(('EDA_Visualizations/Histograms/'+ column_name + '_histogram.jpg'))
    plt.close()

# %%
create_histo(df, 'teen_births')
create_histo(df, 'childhood_immunizations')
create_histo(df, '%_non_hispanic_white')

# %% [markdown]
# # Starting off with teen_births variable, we can see that there is a significant difference between low, medium, and high teen births' median values for the uninsurance rate. The p-value is about 1.018 e-115.

# %%
df.teen_births.describe()
# Out:
# count    2997.000000
# mean       32.101382
# std        15.130680
# min         2.394971
# 25%        20.853081
# 50%        30.613054
# 75%        41.900545
# max       110.236220
# Name: teen_births, dtype: float64

# %%
low_threshold = (df.teen_births.max() - 0)/3
high_threshold = (df.teen_births.max() - 0) * 2/3

teen_birth_low_df = df[df.teen_births < low_threshold]
teen_birth_med_df = df[(df.teen_births >= low_threshold) & (df.teen_births <= high_threshold)]
teen_birth_high_df = df[df.teen_births > high_threshold]

# Perform the Kruskal-Wallis test for uninsured columns. 
scipy.stats.kruskal(teen_birth_low_df.uninsured, teen_birth_med_df.uninsured, teen_birth_high_df.uninsured)
# Out:
# KruskalResult(statistic=529.5579949987978, pvalue=1.0184564480701128e-115)

# %% [markdown]
# # There is also statistical difference between low and high rates of childhood immunization rates, when it comes to uninsurance rates.

# %%
# Doing the same for childhood_immunizations
df.childhood_immunizations.describe()
# Out:
# count    72.000000
# mean      0.699242
# std       0.083122
# min       0.426600
# 25%       0.651225
# 50%       0.714150
# 75%       0.761375
# max       0.823200
# Name: childhood_immunizations, dtype: float64

# %%
# Because there are no values less than 0.33, the data will be split only into two groups instead of three. 
child_immun_low_df = df[df.childhood_immunizations < 0.5] # Because this df is empty, will not include

child_immun_high_df = df[df.childhood_immunizations >=0.5]

# Perform the Kruskal-Wallis test for uninsured columns. 
scipy.stats.kruskal(child_immun_low_df.uninsured, child_immun_high_df.uninsured)
# Out:
# KruskalResult(statistic=4.960861056751469, pvalue=0.02592729400798094)

# %% [markdown]
# # The results for different percentage of white population's uninsurance rates is inconclusive looking at low, medium, and high. If we only look at medium and high results, however, we do get significant differences for the uninsurance rate.

# %%
# Doing the same for %_non_hispanic_white
df['%_non_hispanic_white'].describe()
# Out:
# count    3141.000000
# mean        0.762984
# std         0.201406
# min         0.027604
# 25%         0.645874
# 50%         0.837249
# 75%         0.925094
# max         0.979227
# Name: %_non_hispanic_white, dtype: float64

# %%
low_threshold = 0.330
high_threshold = 0.660

percent_white_low_df = df[df['%_non_hispanic_white'] < low_threshold]
percent_white_med_df = df[(df['%_non_hispanic_white'] >= low_threshold) & (df['%_non_hispanic_white'] <= high_threshold)]
percent_white_high_df = df[df['%_non_hispanic_white'] > high_threshold]

# Perform the Kruskal-Wallis test for uninsured columns. 
print(scipy.stats.kruskal(percent_white_low_df.uninsured, percent_white_med_df.uninsured, percent_white_high_df.uninsured))

# Because the Kruskal-Wallis test above returned an nan p-value for these three categories, we perform the same analysis,
# except we now exclude the low category

scipy.stats.kruskal(percent_white_med_df.uninsured, percent_white_high_df.uninsured)
# Out:
# KruskalResult(statistic=nan, pvalue=nan)
# KruskalResult(statistic=438.5547841022832, pvalue=2.2334799498697207e-97)

# %% [markdown]
# # There is significant difference for low, medium, and high groups' uninsurance rates for the variables of teen births, childhood immunizations, and percentage of nonhispanic whites. The bar charts display these differences for those groups

# %%
def create_bar(df_list, df_list_names):
    """
    Creates bar graph from a list of data frames' values. Df_list and df_list_names must have their respective 
    elements in the same order as each other.
    
    df_list: a list of df
    df_list_names: a list of strings containing the df's names
    """
    x = []
    y = []
    for i in range(len(df_list)):
        x.append(df_list_names[i].split('_df')[0])
        y.append(df_list[i].uninsured.median() * 100.0)
    
    plt.bar(x, y)
    plt.xlabel("Category")
    plt.ylabel("Median Uninsurance Percentage")
    plt.title("Uninsurance Rate Differences Amongst Counties Grouped By Category")
    plt.show()
    plt.savefig("EDA_Visualizations/Bar_Charts/{}_categories".format(df_list_names[0].split("_")[:2]))
    plt.close()

teen_birth_dfs = [teen_birth_low_df, teen_birth_med_df, teen_birth_high_df]
teen_birth_names = ['teen_birth_low_df', 'teen_birth_med_df', 'teen_birth_high_df']
create_bar(teen_birth_dfs, teen_birth_names)

child_immun_dfs = [child_immun_low_df, child_immun_high_df]
child_immun_names = ['child_immun_low_df', 'child_immun_high_df']
create_bar(child_immun_dfs, child_immun_names)

percent_white_dfs = [percent_white_med_df, percent_white_high_df]
percent_white_names = ['percent_white_med_df', 'percent_white_high_df']
create_bar(percent_white_dfs, percent_white_names)

# %% [markdown]
# # We'll see the distribution of counties across the nation based on where they belong in the low, medium, or high categories for each variable of interest.
#
# Source: https://plotly.com/python/county-choropleth/

# %%
# Preparing teen births dfs
teen_birth_low_df['value'] = 'Low rate of teen births (less than 36.75 births per 1000 teenagers)'
teen_birth_med_df['value'] = 'Medium rate of teen births (between 36.75 and 73.49 births per 1000 teenagers)'
teen_birth_high_df['value'] = 'High rate of teen births (between 36.75 and 73.49 births per 1000 teenagers)'

teen_birth_df = pd.concat([teen_birth_low_df, teen_birth_med_df, teen_birth_high_df])

teen_birth_df.head()
# Out:
#     state_fips_code  county_fips_code 5_digit_fips_code state_abbreviation  \
# 2                 1                 1             01001                 AL
# 3                 1                 3             01003                 AL
# 6                 1                 9             01009                 AL
# 13                1                23             01023                 AL
# 17                1                31             01031                 AL
#
#               name  premature_death  premature_death_black  \
# 2   Autauga County      8824.057123           10471.252986
# 3   Baldwin County      7224.632160           10042.472874
# 6    Blount County     10908.101822                    NaN
# 13  Choctaw County     12047.187077           12215.473555
# 17   Coffee County      7933.129666           10333.512289
#
#     premature_death_hispanic  premature_death_white  poor_or_fair_health  ...  \
# ...

# %%
colorscale = ['rgb(68.0, 1.0, 84.0)',
    'rgb(66.0, 64.0, 134.0)',
    'rgb(38.0, 130.0, 142.0)']
endpts = list(np.linspace(1, 12, len(colorscale) - 1))
fips = teen_birth_df['5_digit_fips_code'].tolist()
values = teen_birth_df['value'].tolist()

fig = ff.create_choropleth(
    fips=fips, values=values,
    binning_endpoints=endpts,
    colorscale=colorscale,
    show_state_data=False,
    show_hover=True, centroid_marker={'opacity': 0},
    asp=2.9, title='USA by Unemployment %',
    legend_title='% unemployed'
)

fig.layout.template = None
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-199-5d774de9e5ed> in <module>
#       6 values = teen_birth_df['value'].tolist()
#       7
# ----> 8 fig = ff.create_choropleth(
#       9     fips=fips, values=values,
#      10     binning_endpoints=endpts,
#
# /opt/conda/lib/python3.8/site-packages/plotly/figure_factory/_county_choropleth.py in create_choropleth(fips, values, scope, binning_endpoints, colorscale, order, simplify_county, simplify_state, asp, show_hover, show_state_data, state_outline, county_outline, centroid_marker, round_legend_values, exponent_format, legend_title, **layout_options)
#     603     # ensure optional modules imported
#     604     if not _plotly_geo:
# --> 605         raise ValueError(
#     606             """
#     607 The create_choropleth figure factory requires the plotly-geo package.
#
# ValueError:
# ...

# %% [markdown]
# # Now, we are going to repeat the same process, except looking at each state instead of the entire US. For this, we will create a dictionary that has the state abbreviation as key, and another dictionary containing the independent variable and respective r-value as the value.

# %%
state_corr_dict = defaultdict(dict)
for state in df.state_abbreviation.unique():
    state_corr = df[df.state_abbreviation==state].corr()
    print("State of " + state)
    for index in state_corr.index:
        fltr = (state_corr.loc[index]["uninsured"] >= 0.5) | (state_corr.loc[index]["uninsured"] <= -0.5)
        if fltr and index not in ['uninsured', 'uninsured_adults', 'uninsured_children']:
            print(index)
            print(state_corr.loc[index]["uninsured"][fltr])
            
            state_corr_dict[state][index] = state_corr.loc[index]["uninsured"][fltr]
    print("\n")
# Out:
# State of US
#
#
# State of AL
# teen_births
# [0.5425532]
# some_college
# [-0.52330996]
# child_mortality_black
# [0.53721036]
# median_household_income_white
# [-0.55549959]
#
#
# State of AK
# premature_death
# [0.57682274]
# premature_death_black
# [-1.]
# low_birthweight_black
# [-1.]
# low_birthweight_hispanic
# [0.72745775]
# low_birthweight_white
# [0.68963631]
# food_environment_index
# [-0.61795195]
# physical_inactivity
# [0.68260812]
# excessive_drinking
# [-0.60371402]
# teen_births_black
# [1.]
# preventable_hospital_stays_black
# [-1.]
# preventable_hospital_stays_hispanic
# [-0.8018124]
# preventable_hospital_stays_white
# [0.68060224]
# mammography_screening_black
# [1.]
# flu_vaccinations_white
# [0.54638262]
# some_college
# [-0.69104313]
# children_in_poverty_black
# [0.77140783]
# children_in_single_parent_households
# [0.64560105]
# violent_crime
# [-0.65139484]
# injury_deaths
# [0.67262089]
# driving_alone_to_work
# [-0.63045533]
# driving_alone_to_work_black
# ...

# %%
for state in df.state_abbreviation.unique():
    if (state != 'US') and (state != 'DC'):
        print(state)
        strong_state_corr = df[state_corr_dict[state].keys()].corr()
        plt.title("State of " + state)
        
        print(sns.heatmap(strong_state_corr, cmap='vlag'))
        plt.savefig('EDA_Visualizations/Heatmaps/{}_indep_features_heatmap'.format(state), transparent=True,
                    bbox_inches='tight')
        plt.close()
# Out:
# AL
# AxesSubplot(0.125,0.125;0.62x0.755)
# AK
# AxesSubplot(0.125,0.125;0.62x0.755)
# AZ
# AxesSubplot(0.125,0.125;0.62x0.755)
# AR
# AxesSubplot(0.125,0.125;0.62x0.755)
# CA
# AxesSubplot(0.125,0.125;0.62x0.755)
# CO
# AxesSubplot(0.125,0.125;0.62x0.755)
# CT
# AxesSubplot(0.125,0.125;0.62x0.755)
# DE
# AxesSubplot(0.125,0.125;0.62x0.755)
# FL
# AxesSubplot(0.125,0.125;0.62x0.755)
# GA
# AxesSubplot(0.125,0.125;0.62x0.755)
# HI
# AxesSubplot(0.125,0.125;0.62x0.755)
# ID
# AxesSubplot(0.125,0.125;0.62x0.755)
# IL
# AxesSubplot(0.125,0.125;0.62x0.755)
# IN
# AxesSubplot(0.125,0.125;0.62x0.755)
# IA
# AxesSubplot(0.125,0.125;0.62x0.755)
# KS
# AxesSubplot(0.125,0.125;0.62x0.755)
# KY
# AxesSubplot(0.125,0.125;0.62x0.755)
# LA
# AxesSubplot(0.125,0.125;0.62x0.755)
# ME
# AxesSubplot(0.125,0.125;0.62x0.755)
# MD
# AxesSubplot(0.125,0.125;0.62x0.755)
# MA
# AxesSubplot(0.125,0.125;0.62x0.755)
# MI
# AxesSubplot(0.125,0.125;0.62x0.755)
# MN
# AxesSubplot(0.125,0.125;0.62x0.755)
# MS
# ...

# %%
state_corr_dict
# Out:
# defaultdict(dict,
#             {'AL': {'teen_births': array([0.5425532]),
#               'some_college': array([-0.52330996]),
#               'child_mortality_black': array([0.53721036]),
#               'median_household_income_white': array([-0.55549959])},
#              'AK': {'low_birthweight_black': array([-1.]),
#               'low_birthweight_hispanic': array([0.72745775]),
#               'low_birthweight_white': array([0.68963631]),
#               'food_environment_index': array([-0.61795195]),
#               'physical_inactivity': array([0.68260812]),
#               'excessive_drinking': array([-0.60371402]),
#               'teen_births_black': array([1.]),
#               'preventable_hospital_stays_black': array([-1.]),
#               'preventable_hospital_stays_hispanic': array([-0.8018124]),
#               'preventable_hospital_stays_white': array([0.68060224]),
#               'mammography_screening_black': array([1.]),
# ...

# %%
def create_msno(df, start_index, final_index):
    plt.close()
    for state in df.state_abbreviation.unique()[start_index:final_index]:   
        corr = df[df.state_abbreviation==state].drop(columns=['state_fips_code', 'county_fips_code', '5_digit_fips_code', 'uninsured', 'uninsured_adults',
                                'uninsured_children']).corr()
        corr = corr[(corr > -0.7) & (corr < 0.7)]
        (msn.matrix(corr))

        plt.title("State of " + state)


create_msno(df, 0, 20)
create_msno(df, 20, 40)
create_msno(df, 40, 52)
# Out:
# /opt/conda/lib/python3.8/site-packages/missingno/missingno.py:50: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=figsize)

# %% [markdown]
# Source: https://www.geeksforgeeks.org/detecting-multicollinearity-with-vif-python/

# %%
# Computing Variance Inflation Factors
sub_df = df[df.state_abbreviation=='TX'].drop(columns=['state_fips_code', 'county_fips_code', '5_digit_fips_code',
                                                       'state_abbreviation', 'name','uninsured', 'uninsured_children',
                                                       'uninsured_adults'])
vif_data_copy = sub_df.copy()


while not vif_data_copy.empty:
    interesting_vars = sub_df.columns.to_list()
    X = sub_df[interesting_vars]
    print(X)

    # VIF dataframe
    vif_data = pd.DataFrame()
    vif_data["feature"] = X.columns

    # calculating VIF for each feature
    
    vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                              for i in range(len(X.columns))]

    print(vif_data)
    break

    if float('inf') in vif_data["VIF"].unique():
        feature_list = vif_data[vif_data['VIF']==float("inf")].feature.to_list()
        sub_df = sub_df.drop(columns=feature_list[0])
        vif_data_copy = vif_data[vif_data.feature!= feature_list[0]]
    elif ~ vif_data[vif_data['VIF'] >= 5].empty:
        feature_list = vif_data[vif_data['VIF']>= 5].feature.to_list()
        sub_df = sub_df.drop(columns=feature_list[0])
        vif_data_copy = vif_data[vif_data.feature!= feature_list[0]]
    else:
        vif_data_copy = pd.DataFrame()

sub_df
# Out:
#       premature_death  premature_death_black  premature_death_hispanic  \
# 2567      6681.323364                    NaN                       NaN
# 2568     10272.949118           12962.159784              10880.315229
# 2569      7952.973251                    NaN               7774.144329
# 2570      9018.498513           14014.161619               4450.704830
# 2571      9315.870361                    NaN               6088.571549
# ...               ...                    ...                       ...
# 2817      9457.366431           11529.284333               5200.873212
# 2818      8031.592211                    NaN               6346.983631
# 2819     10234.600248                    NaN                       NaN
# 2820      6770.768596                    NaN                       NaN
# 2821      9389.759155                    NaN                       NaN
#
#       premature_death_white  poor_or_fair_health  poor_physical_health_days  \
# ...
